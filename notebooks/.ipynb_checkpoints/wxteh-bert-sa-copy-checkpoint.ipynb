# %% [markdown]
# # Libraries Import

# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import random

# %%
# !pip install torch
# Out:
# Collecting torch
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# Requirement already satisfied: filelock in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (1.12)
# Collecting networkx (from torch)
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: jinja2 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch)
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch)
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch)
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch)
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch)
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch)
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch)
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch)
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (2.14.3)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch)
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting triton==2.0.0 (from torch)
#   Using cached triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Requirement already satisfied: setuptools in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (63.2.0)
# Requirement already satisfied: wheel in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.41.2)
# Requirement already satisfied: cmake in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from triton==2.0.0->torch) (3.27.5)
# Requirement already satisfied: lit in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch
# Successfully installed networkx-3.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 triton-2.0.0

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (2.0.1)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.15.2%2Bcpu-cp310-cp310-linux_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 17.2 MB/s eta 0:00:0000:0100:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.0.2%2Bcpu-cp310-cp310-linux_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 1.7 MB/s eta 0:00:0000:0100:020m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/4.1 MB 94.5 MB/s eta 0:00:01
# Requirement already satisfied: filelock in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (63.2.0)
# Requirement already satisfied: wheel in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.41.2)
# Requirement already satisfied: cmake in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from triton==2.0.0->torch) (3.27.5)
# Requirement already satisfied: lit in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: numpy in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torchvision) (1.25.2)
# Requirement already satisfied: requests in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from torchvision) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from requests->torchvision) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /home/wxteh/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: torchvision, torchaudio
# Successfully installed torchaudio-2.0.2+cpu torchvision-0.15.2+cpu

# %% [markdown]
# # Data

# %% [markdown]
# ## Data import

# %%
file_path = "../raw_data/reviews_cleaned.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# ## Data exploration

# %%
df.head()
# Out:
#                                       review_content
# 0     Looks durable Charging is fine tooNo complains
# 1             Charging is really fast, good product.
# 2               Till now satisfied with the quality.
# 3  This is a good product . The charging speed is...
# 4                      Good quality, would recommend

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11012 entries, 0 to 11011
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   review_content  11008 non-null  object
# dtypes: object(1)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#        review_content
# count           11008
# unique           7668
# top              Good
# freq              362

# %%
df.shape
# Out:
# (11012, 1)

# %%
df["review_content"][0]
# Out:
# 'Looks durable Charging is fine tooNo complains'

# %%
print(df.isna().sum())
# Out:
# review_content    4
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#      review_content
# 5861            NaN
# 8233            NaN
# 9122            NaN
# 9953            NaN

# %% [markdown]
# ## Data Cleaning

# %%
# Drop NAN
df = df.dropna()

# %%
print(df.isna().sum())
# Out:
# review_content    0
# dtype: int64

# %% [markdown]
# # BERT

# %% [markdown]
# ## Instantiate Model

# %%
tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")

model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 3
#       1 tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
# ----> 3 model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
#
# File ~/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages/transformers/utils/import_utils.py:1124, in DummyObject.__getattribute__(cls, key)
#    1122 if key.startswith("_") and key != "_from_config":
#    1123     return super().__getattribute__(key)
# -> 1124 requires_backends(cls, cls._backends)
#
# File ~/.pyenv/versions/3.10.6/envs/amazon-customer-review-analysis/lib/python3.10/site-packages/transformers/utils/import_utils.py:1112, in requires_backends(obj, backends)
#    1110 failed = [msg.format(name) for available, msg in checks if not available()]
#    1111 if failed:
# -> 1112     raise ImportError("".join(failed))
#
# ImportError:
# AutoModelForSequenceClassification requires the PyTorch library but it was not found in your environment. Checkout the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %% [markdown]
# ## Encode and calculate Sentiment

# %%
tokens = tokenizer.encode("Ganz gut", return_tensors="pt")

# %%
result = model(tokens)

# %%
result.logits
# Out:
# tensor([[-2.2008, -1.5792,  0.6085,  1.6348,  1.1937]],
#        grad_fn=<AddmmBackward0>)

# %%
int(torch.argmax(result.logits))+1
# Out:
# 4

# %% [markdown]
# ## Score our Data

# %% [markdown]
# ### BERT with Pseudodf

# %% [markdown]
# #### Create pseudo dataframe as playground

# %%
# Create some example data with titles
pseudo_data = {
    'Username': ['user1', 'user2', 'user3', 'user4', 'user5', 'user6', 'user7', 'user8', 'user9', 'user10'],
    'ProductID': [101, 101, 101, 102, 102, 103, 104, 104, 105, 106],
    'Title': [
        'Excellent Product',
        'Good Purchase',
        'Average Quality',
        'Very Disappointed',
        'Highly Recommended',
        'Functional but Not Perfect',
        'Waste of Money',
        'Satisfactory Purchase',
        'Exceeded Expectations',
        'Mixed Feelings'],
    'Review': [
        'Excellent',
        'Good product.',
        'Average quality for the price.',
        'Not recommended. Very disappointed.',
        'Awesome! I love it. Highly recommended.',
        'Could be better, but it works.',
        'Terrible. Waste of money.',
        'Satisfactory purchase. No complaints.',
        'This product exceeded my expectations. Great value!',
        'I have mixed feelings about this product.']
}

# Add random additional sentences to some reviews
for i in range(5):
    index = random.randint(0, 9)
    additional_sentences = [
        'I received it on time.',
        'The packaging was damaged, but the product was intact.',
        'The customer service was helpful.',
        'The color is not as described in the picture.',
        'I would buy it again in the future.']
    pseudo_data['Review'][index] += ' ' + ' '.join(random.sample(additional_sentences, random.randint(1, 3)))

# Create a DataFrame named pseudo_df
pseudo_df = pd.DataFrame(pseudo_data)

# Display the DataFrame
pseudo_df
# Out:
#   Username  ProductID                       Title  \
# 0    user1        101           Excellent Product
# 1    user2        101               Good Purchase
# 2    user3        101             Average Quality
# 3    user4        102           Very Disappointed
# 4    user5        102          Highly Recommended
# 5    user6        103  Functional but Not Perfect
# 6    user7        104              Waste of Money
# 7    user8        104       Satisfactory Purchase
# 8    user9        105       Exceeded Expectations
# 9   user10        106              Mixed Feelings
#
#                                               Review
# 0                                          Excellent
# 1  Good product. I would buy it again in the futu...
# 2                     Average quality for the price.
# 3                Not recommended. Very disappointed.
# 4  Awesome! I love it. Highly recommended. The pa...
# 5                     Could be better, but it works.
# 6                          Terrible. Waste of money.
# 7              Satisfactory purchase. No complaints.
# 8  This product exceeded my expectations. Great v...
# 9  I have mixed feelings about this product. I wo...

# %% [markdown]
# #### Loop through data and pass to model

# %%
# function to to get a review and pass through the model
def sentiment_score(review):
    tokens = tokenizer.encode(review, return_tensors="pt")
    result = model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
pseudo_df["Sentiment Title"] = pseudo_df["Title"].apply(lambda x: sentiment_score(x[:512]))

# %%
pseudo_df["Sentiment Review"] = pseudo_df["Review"].apply(lambda x: sentiment_score(x[:512]))

# %%
pseudo_df
# Out:
#   Username  ProductID                       Title  \
# 0    user1        101           Excellent Product
# 1    user2        101               Good Purchase
# 2    user3        101             Average Quality
# 3    user4        102           Very Disappointed
# 4    user5        102          Highly Recommended
# 5    user6        103  Functional but Not Perfect
# 6    user7        104              Waste of Money
# 7    user8        104       Satisfactory Purchase
# 8    user9        105       Exceeded Expectations
# 9   user10        106              Mixed Feelings
#
#                                               Review  Sentiment Title  \
# 0                                          Excellent                5
# 1  Good product. I would buy it again in the futu...                4
# 2                     Average quality for the price.                3
# 3                Not recommended. Very disappointed.                1
# 4  Awesome! I love it. Highly recommended. The pa...                5
# 5                     Could be better, but it works.                3
# 6                          Terrible. Waste of money.                1
# 7              Satisfactory purchase. No complaints.                4
# 8  This product exceeded my expectations. Great v...                5
# 9  I have mixed feelings about this product. I wo...                3
#
#    Sentiment Review
# 0                 5
# 1                 4
# 2                 3
# 3                 1
# 4                 5
# 5                 3
# 6                 1
# 7                 4
# 8                 5
# 9                 3

# %% [markdown]
# ### BERT with our data

# %%
def sentiment_score(review):
    tokens = tokenizer.encode(review, return_tensors="pt")
    result = model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
# Split the DataFrame into batches of 512 rows
batch_size = 512
num_batches = len(df) // batch_size + 1

# Initialize an empty list to store sentiment scores
sentiment_scores = []

# Iterate through the batches
for i in range(num_batches):
    start_idx = i * batch_size
    end_idx = (i + 1) * batch_size
    batch_reviews = df["review_content"].iloc[start_idx:end_idx]
    
    # Iterate through the rows within the batch
    for j, review in enumerate(batch_reviews):
        # Check if the review is NaN or None
        if pd.notna(review):
            sentiment = sentiment_score(review[:512])
            sentiment_scores.append(sentiment)
            
            # Calculate the row number
            row_number = i * batch_size + j + 1
            
            # Print the progress
            print(f"Row {row_number} in Batch {i + 1} is done")

# Add the sentiment scores to the DataFrame
df["Sentiment"] = sentiment_scores
# Out:
# Row 1 in Batch 1 is done
# Row 2 in Batch 1 is done
# Row 3 in Batch 1 is done
# Row 4 in Batch 1 is done
# Row 5 in Batch 1 is done
# Row 6 in Batch 1 is done
# Row 7 in Batch 1 is done
# Row 8 in Batch 1 is done
# Row 9 in Batch 1 is done
# Row 10 in Batch 1 is done
# Row 11 in Batch 1 is done
# Row 12 in Batch 1 is done
# Row 13 in Batch 1 is done
# Row 14 in Batch 1 is done
# Row 15 in Batch 1 is done
# Row 16 in Batch 1 is done
# Row 17 in Batch 1 is done
# Row 18 in Batch 1 is done
# Row 19 in Batch 1 is done
# Row 20 in Batch 1 is done
# Row 21 in Batch 1 is done
# Row 22 in Batch 1 is done
# Row 23 in Batch 1 is done
# Row 24 in Batch 1 is done
# Row 25 in Batch 1 is done
# Row 26 in Batch 1 is done
# Row 27 in Batch 1 is done
# Row 28 in Batch 1 is done
# Row 29 in Batch 1 is done
# Row 30 in Batch 1 is done
# Row 31 in Batch 1 is done
# Row 32 in Batch 1 is done
# Row 33 in Batch 1 is done
# Row 34 in Batch 1 is done
# Row 35 in Batch 1 is done
# Row 36 in Batch 1 is done
# Row 37 in Batch 1 is done
# Row 38 in Batch 1 is done
# Row 39 in Batch 1 is done
# Row 40 in Batch 1 is done
# Row 41 in Batch 1 is done
# Row 42 in Batch 1 is done
# Row 43 in Batch 1 is done
# Row 44 in Batch 1 is done
# Row 45 in Batch 1 is done
# Row 46 in Batch 1 is done
# Row 47 in Batch 1 is done
# Row 48 in Batch 1 is done
# Row 49 in Batch 1 is done
# Row 50 in Batch 1 is done
# Row 51 in Batch 1 is done
# Row 52 in Batch 1 is done
# Row 53 in Batch 1 is done
# Row 54 in Batch 1 is done
# Row 55 in Batch 1 is done
# Row 56 in Batch 1 is done
# Row 57 in Batch 1 is done
# Row 58 in Batch 1 is done
# Row 59 in Batch 1 is done
# Row 60 in Batch 1 is done
# Row 61 in Batch 1 is done
# Row 62 in Batch 1 is done
# Row 63 in Batch 1 is done
# Row 64 in Batch 1 is done
# Row 65 in Batch 1 is done
# Row 66 in Batch 1 is done
# Row 67 in Batch 1 is done
# Row 68 in Batch 1 is done
# Row 69 in Batch 1 is done
# Row 70 in Batch 1 is done
# Row 71 in Batch 1 is done
# Row 72 in Batch 1 is done
# Row 73 in Batch 1 is done
# Row 74 in Batch 1 is done
# Row 75 in Batch 1 is done
# Row 76 in Batch 1 is done
# Row 77 in Batch 1 is done
# Row 78 in Batch 1 is done
# Row 79 in Batch 1 is done
# Row 80 in Batch 1 is done
# Row 81 in Batch 1 is done
# Row 82 in Batch 1 is done
# Row 83 in Batch 1 is done
# Row 84 in Batch 1 is done
# Row 85 in Batch 1 is done
# Row 86 in Batch 1 is done
# Row 87 in Batch 1 is done
# Row 88 in Batch 1 is done
# Row 89 in Batch 1 is done
# Row 90 in Batch 1 is done
# Row 91 in Batch 1 is done
# Row 92 in Batch 1 is done
# Row 93 in Batch 1 is done
# Row 94 in Batch 1 is done
# Row 95 in Batch 1 is done
# Row 96 in Batch 1 is done
# Row 97 in Batch 1 is done
# Row 98 in Batch 1 is done
# Row 99 in Batch 1 is done
# Row 100 in Batch 1 is done
# Row 101 in Batch 1 is done
# Row 102 in Batch 1 is done
# Row 103 in Batch 1 is done
# Row 104 in Batch 1 is done
# Row 105 in Batch 1 is done
# Row 106 in Batch 1 is done
# Row 107 in Batch 1 is done
# Row 108 in Batch 1 is done
# Row 109 in Batch 1 is done
# Row 110 in Batch 1 is done
# Row 111 in Batch 1 is done
# Row 112 in Batch 1 is done
# Row 113 in Batch 1 is done
# Row 114 in Batch 1 is done
# Row 115 in Batch 1 is done
# Row 116 in Batch 1 is done
# Row 117 in Batch 1 is done
# Row 118 in Batch 1 is done
# Row 119 in Batch 1 is done
# Row 120 in Batch 1 is done
# Row 121 in Batch 1 is done
# Row 122 in Batch 1 is done
# Row 123 in Batch 1 is done
# Row 124 in Batch 1 is done
# Row 125 in Batch 1 is done
# Row 126 in Batch 1 is done
# Row 127 in Batch 1 is done
# Row 128 in Batch 1 is done
# Row 129 in Batch 1 is done
# Row 130 in Batch 1 is done
# Row 131 in Batch 1 is done
# Row 132 in Batch 1 is done
# Row 133 in Batch 1 is done
# Row 134 in Batch 1 is done
# Row 135 in Batch 1 is done
# Row 136 in Batch 1 is done
# Row 137 in Batch 1 is done
# Row 138 in Batch 1 is done
# Row 139 in Batch 1 is done
# Row 140 in Batch 1 is done
# Row 141 in Batch 1 is done
# Row 142 in Batch 1 is done
# Row 143 in Batch 1 is done
# Row 144 in Batch 1 is done
# Row 145 in Batch 1 is done
# Row 146 in Batch 1 is done
# Row 147 in Batch 1 is done
# Row 148 in Batch 1 is done
# Row 149 in Batch 1 is done
# Row 150 in Batch 1 is done
# Row 151 in Batch 1 is done
# Row 152 in Batch 1 is done
# Row 153 in Batch 1 is done
# Row 154 in Batch 1 is done
# Row 155 in Batch 1 is done
# Row 156 in Batch 1 is done
# Row 157 in Batch 1 is done
# Row 158 in Batch 1 is done
# Row 159 in Batch 1 is done
# Row 160 in Batch 1 is done
# Row 161 in Batch 1 is done
# Row 162 in Batch 1 is done
# Row 163 in Batch 1 is done
# Row 164 in Batch 1 is done
# Row 165 in Batch 1 is done
# Row 166 in Batch 1 is done
# Row 167 in Batch 1 is done
# Row 168 in Batch 1 is done
# Row 169 in Batch 1 is done
# Row 170 in Batch 1 is done
# Row 171 in Batch 1 is done
# Row 172 in Batch 1 is done
# Row 173 in Batch 1 is done
# Row 174 in Batch 1 is done
# Row 175 in Batch 1 is done
# Row 176 in Batch 1 is done
# Row 177 in Batch 1 is done
# Row 178 in Batch 1 is done
# Row 179 in Batch 1 is done
# Row 180 in Batch 1 is done
# Row 181 in Batch 1 is done
# Row 182 in Batch 1 is done
# Row 183 in Batch 1 is done
# Row 184 in Batch 1 is done
# Row 185 in Batch 1 is done
# Row 186 in Batch 1 is done
# Row 187 in Batch 1 is done
# Row 188 in Batch 1 is done
# Row 189 in Batch 1 is done
# Row 190 in Batch 1 is done
# Row 191 in Batch 1 is done
# Row 192 in Batch 1 is done
# Row 193 in Batch 1 is done
# Row 194 in Batch 1 is done
# Row 195 in Batch 1 is done
# Row 196 in Batch 1 is done
# Row 197 in Batch 1 is done
# Row 198 in Batch 1 is done
# Row 199 in Batch 1 is done
# Row 200 in Batch 1 is done
# Row 201 in Batch 1 is done
# Row 202 in Batch 1 is done
# Row 203 in Batch 1 is done
# Row 204 in Batch 1 is done
# Row 205 in Batch 1 is done
# Row 206 in Batch 1 is done
# Row 207 in Batch 1 is done
# Row 208 in Batch 1 is done
# Row 209 in Batch 1 is done
# Row 210 in Batch 1 is done
# Row 211 in Batch 1 is done
# Row 212 in Batch 1 is done
# Row 213 in Batch 1 is done
# Row 214 in Batch 1 is done
# Row 215 in Batch 1 is done
# Row 216 in Batch 1 is done
# Row 217 in Batch 1 is done
# Row 218 in Batch 1 is done
# Row 219 in Batch 1 is done
# Row 220 in Batch 1 is done
# Row 221 in Batch 1 is done
# Row 222 in Batch 1 is done
# Row 223 in Batch 1 is done
# Row 224 in Batch 1 is done
# Row 225 in Batch 1 is done
# Row 226 in Batch 1 is done
# Row 227 in Batch 1 is done
# Row 228 in Batch 1 is done
# Row 229 in Batch 1 is done
# Row 230 in Batch 1 is done
# Row 231 in Batch 1 is done
# Row 232 in Batch 1 is done
# Row 233 in Batch 1 is done
# Row 234 in Batch 1 is done
# Row 235 in Batch 1 is done
# Row 236 in Batch 1 is done
# Row 237 in Batch 1 is done
# Row 238 in Batch 1 is done
# Row 239 in Batch 1 is done
# Row 240 in Batch 1 is done
# Row 241 in Batch 1 is done
# Row 242 in Batch 1 is done
# Row 243 in Batch 1 is done
# Row 244 in Batch 1 is done
# Row 245 in Batch 1 is done
# Row 246 in Batch 1 is done
# Row 247 in Batch 1 is done
# Row 248 in Batch 1 is done
# Row 249 in Batch 1 is done
# Row 250 in Batch 1 is done
# Row 251 in Batch 1 is done
# Row 252 in Batch 1 is done
# Row 253 in Batch 1 is done
# Row 254 in Batch 1 is done
# Row 255 in Batch 1 is done
# Row 256 in Batch 1 is done
# Row 257 in Batch 1 is done
# Row 258 in Batch 1 is done
# Row 259 in Batch 1 is done
# Row 260 in Batch 1 is done
# Row 261 in Batch 1 is done
# Row 262 in Batch 1 is done
# Row 263 in Batch 1 is done
# Row 264 in Batch 1 is done
# Row 265 in Batch 1 is done
# Row 266 in Batch 1 is done
# Row 267 in Batch 1 is done
# Row 268 in Batch 1 is done
# Row 269 in Batch 1 is done
# Row 270 in Batch 1 is done
# Row 271 in Batch 1 is done
# Row 272 in Batch 1 is done
# Row 273 in Batch 1 is done
# Row 274 in Batch 1 is done
# Row 275 in Batch 1 is done
# Row 276 in Batch 1 is done
# Row 277 in Batch 1 is done
# Row 278 in Batch 1 is done
# Row 279 in Batch 1 is done
# Row 280 in Batch 1 is done
# Row 281 in Batch 1 is done
# Row 282 in Batch 1 is done
# Row 283 in Batch 1 is done
# Row 284 in Batch 1 is done
# Row 285 in Batch 1 is done
# Row 286 in Batch 1 is done
# Row 287 in Batch 1 is done
# Row 288 in Batch 1 is done
# Row 289 in Batch 1 is done
# Row 290 in Batch 1 is done
# Row 291 in Batch 1 is done
# Row 292 in Batch 1 is done
# Row 293 in Batch 1 is done
# Row 294 in Batch 1 is done
# Row 295 in Batch 1 is done
# Row 296 in Batch 1 is done
# Row 297 in Batch 1 is done
# Row 298 in Batch 1 is done
# Row 299 in Batch 1 is done
# Row 300 in Batch 1 is done
# Row 301 in Batch 1 is done
# Row 302 in Batch 1 is done
# Row 303 in Batch 1 is done
# Row 304 in Batch 1 is done
# Row 305 in Batch 1 is done
# Row 306 in Batch 1 is done
# Row 307 in Batch 1 is done
# Row 308 in Batch 1 is done
# Row 309 in Batch 1 is done
# Row 310 in Batch 1 is done
# Row 311 in Batch 1 is done
# Row 312 in Batch 1 is done
# Row 313 in Batch 1 is done
# Row 314 in Batch 1 is done
# Row 315 in Batch 1 is done
# Row 316 in Batch 1 is done
# Row 317 in Batch 1 is done
# Row 318 in Batch 1 is done
# Row 319 in Batch 1 is done
# Row 320 in Batch 1 is done
# Row 321 in Batch 1 is done
# Row 322 in Batch 1 is done
# Row 323 in Batch 1 is done
# Row 324 in Batch 1 is done
# Row 325 in Batch 1 is done
# Row 326 in Batch 1 is done
# Row 327 in Batch 1 is done
# Row 328 in Batch 1 is done
# Row 329 in Batch 1 is done
# Row 330 in Batch 1 is done
# Row 331 in Batch 1 is done
# Row 332 in Batch 1 is done
# Row 333 in Batch 1 is done
# Row 334 in Batch 1 is done
# Row 335 in Batch 1 is done
# Row 336 in Batch 1 is done
# Row 337 in Batch 1 is done
# Row 338 in Batch 1 is done
# Row 339 in Batch 1 is done
# Row 340 in Batch 1 is done
# Row 341 in Batch 1 is done
# Row 342 in Batch 1 is done
# Row 343 in Batch 1 is done
# Row 344 in Batch 1 is done
# Row 345 in Batch 1 is done
# Row 346 in Batch 1 is done
# Row 347 in Batch 1 is done
# Row 348 in Batch 1 is done
# Row 349 in Batch 1 is done
# Row 350 in Batch 1 is done
# Row 351 in Batch 1 is done
# Row 352 in Batch 1 is done
# Row 353 in Batch 1 is done
# Row 354 in Batch 1 is done
# Row 355 in Batch 1 is done
# Row 356 in Batch 1 is done
# Row 357 in Batch 1 is done
# Row 358 in Batch 1 is done
# Row 359 in Batch 1 is done
# Row 360 in Batch 1 is done
# Row 361 in Batch 1 is done
# Row 362 in Batch 1 is done
# Row 363 in Batch 1 is done
# Row 364 in Batch 1 is done
# Row 365 in Batch 1 is done
# Row 366 in Batch 1 is done
# Row 367 in Batch 1 is done
# Row 368 in Batch 1 is done
# Row 369 in Batch 1 is done
# Row 370 in Batch 1 is done
# Row 371 in Batch 1 is done
# Row 372 in Batch 1 is done
# Row 373 in Batch 1 is done
# Row 374 in Batch 1 is done
# Row 375 in Batch 1 is done
# Row 376 in Batch 1 is done
# Row 377 in Batch 1 is done
# Row 378 in Batch 1 is done
# Row 379 in Batch 1 is done
# Row 380 in Batch 1 is done
# Row 381 in Batch 1 is done
# Row 382 in Batch 1 is done
# Row 383 in Batch 1 is done
# Row 384 in Batch 1 is done
# Row 385 in Batch 1 is done
# Row 386 in Batch 1 is done
# Row 387 in Batch 1 is done
# Row 388 in Batch 1 is done
# Row 389 in Batch 1 is done
# Row 390 in Batch 1 is done
# Row 391 in Batch 1 is done
# Row 392 in Batch 1 is done
# Row 393 in Batch 1 is done
# Row 394 in Batch 1 is done
# Row 395 in Batch 1 is done
# Row 396 in Batch 1 is done
# Row 397 in Batch 1 is done
# Row 398 in Batch 1 is done
# Row 399 in Batch 1 is done
# Row 400 in Batch 1 is done
# Row 401 in Batch 1 is done
# Row 402 in Batch 1 is done
# Row 403 in Batch 1 is done
# Row 404 in Batch 1 is done
# Row 405 in Batch 1 is done
# Row 406 in Batch 1 is done
# Row 407 in Batch 1 is done
# Row 408 in Batch 1 is done
# Row 409 in Batch 1 is done
# Row 410 in Batch 1 is done
# Row 411 in Batch 1 is done
# Row 412 in Batch 1 is done
# Row 413 in Batch 1 is done
# Row 414 in Batch 1 is done
# Row 415 in Batch 1 is done
# Row 416 in Batch 1 is done
# Row 417 in Batch 1 is done
# Row 418 in Batch 1 is done
# Row 419 in Batch 1 is done
# Row 420 in Batch 1 is done
# Row 421 in Batch 1 is done
# Row 422 in Batch 1 is done
# Row 423 in Batch 1 is done
# Row 424 in Batch 1 is done
# Row 425 in Batch 1 is done
# Row 426 in Batch 1 is done
# Row 427 in Batch 1 is done
# Row 428 in Batch 1 is done
# Row 429 in Batch 1 is done
# Row 430 in Batch 1 is done
# Row 431 in Batch 1 is done
# Row 432 in Batch 1 is done
# Row 433 in Batch 1 is done
# Row 434 in Batch 1 is done
# Row 435 in Batch 1 is done
# Row 436 in Batch 1 is done
# Row 437 in Batch 1 is done
# Row 438 in Batch 1 is done
# Row 439 in Batch 1 is done
# Row 440 in Batch 1 is done
# Row 441 in Batch 1 is done
# Row 442 in Batch 1 is done
# Row 443 in Batch 1 is done
# Row 444 in Batch 1 is done
# Row 445 in Batch 1 is done
# Row 446 in Batch 1 is done
# Row 447 in Batch 1 is done
# Row 448 in Batch 1 is done
# Row 449 in Batch 1 is done
# Row 450 in Batch 1 is done
# Row 451 in Batch 1 is done
# Row 452 in Batch 1 is done
# Row 453 in Batch 1 is done
# Row 454 in Batch 1 is done
# Row 455 in Batch 1 is done
# Row 456 in Batch 1 is done
# Row 457 in Batch 1 is done
# Row 458 in Batch 1 is done
# Row 459 in Batch 1 is done
# Row 460 in Batch 1 is done
# Row 461 in Batch 1 is done
# Row 462 in Batch 1 is done
# Row 463 in Batch 1 is done
# Row 464 in Batch 1 is done
# Row 465 in Batch 1 is done
# Row 466 in Batch 1 is done
# Row 467 in Batch 1 is done
# Row 468 in Batch 1 is done
# Row 469 in Batch 1 is done
# Row 470 in Batch 1 is done
# Row 471 in Batch 1 is done
# Row 472 in Batch 1 is done
# Row 473 in Batch 1 is done
# Row 474 in Batch 1 is done
# Row 475 in Batch 1 is done
# Row 476 in Batch 1 is done
# Row 477 in Batch 1 is done
# Row 478 in Batch 1 is done
# Row 479 in Batch 1 is done
# Row 480 in Batch 1 is done
# Row 481 in Batch 1 is done
# Row 482 in Batch 1 is done
# Row 483 in Batch 1 is done
# Row 484 in Batch 1 is done
# Row 485 in Batch 1 is done
# Row 486 in Batch 1 is done
# Row 487 in Batch 1 is done
# Row 488 in Batch 1 is done
# Row 489 in Batch 1 is done
# Row 490 in Batch 1 is done
# Row 491 in Batch 1 is done
# Row 492 in Batch 1 is done
# Row 493 in Batch 1 is done
# Row 494 in Batch 1 is done
# Row 495 in Batch 1 is done
# Row 496 in Batch 1 is done
# Row 497 in Batch 1 is done
# Row 498 in Batch 1 is done
# Row 499 in Batch 1 is done
# Row 500 in Batch 1 is done
# Row 501 in Batch 1 is done
# Row 502 in Batch 1 is done
# Row 503 in Batch 1 is done
# Row 504 in Batch 1 is done
# Row 505 in Batch 1 is done
# Row 506 in Batch 1 is done
# Row 507 in Batch 1 is done
# Row 508 in Batch 1 is done
# Row 509 in Batch 1 is done
# Row 510 in Batch 1 is done
# Row 511 in Batch 1 is done
# Row 512 in Batch 1 is done
# Row 513 in Batch 2 is done
# Row 514 in Batch 2 is done
# Row 515 in Batch 2 is done
# Row 516 in Batch 2 is done
# Row 517 in Batch 2 is done
# Row 518 in Batch 2 is done
# Row 519 in Batch 2 is done
# Row 520 in Batch 2 is done
# Row 521 in Batch 2 is done
# Row 522 in Batch 2 is done
# Row 523 in Batch 2 is done
# Row 524 in Batch 2 is done
# Row 525 in Batch 2 is done
# Row 526 in Batch 2 is done
# Row 527 in Batch 2 is done
# Row 528 in Batch 2 is done
# Row 529 in Batch 2 is done
# Row 530 in Batch 2 is done
# Row 531 in Batch 2 is done
# Row 532 in Batch 2 is done
# Row 533 in Batch 2 is done
# Row 534 in Batch 2 is done
# Row 535 in Batch 2 is done
# Row 536 in Batch 2 is done
# Row 537 in Batch 2 is done
# Row 538 in Batch 2 is done
# Row 539 in Batch 2 is done
# Row 540 in Batch 2 is done
# Row 541 in Batch 2 is done
# Row 542 in Batch 2 is done
# Row 543 in Batch 2 is done
# Row 544 in Batch 2 is done
# Row 545 in Batch 2 is done
# Row 546 in Batch 2 is done
# Row 547 in Batch 2 is done
# Row 548 in Batch 2 is done
# Row 549 in Batch 2 is done
# Row 550 in Batch 2 is done
# Row 551 in Batch 2 is done
# Row 552 in Batch 2 is done
# Row 553 in Batch 2 is done
# Row 554 in Batch 2 is done
# Row 555 in Batch 2 is done
# Row 556 in Batch 2 is done
# Row 557 in Batch 2 is done
# Row 558 in Batch 2 is done
# Row 559 in Batch 2 is done
# Row 560 in Batch 2 is done
# Row 561 in Batch 2 is done
# Row 562 in Batch 2 is done
# Row 563 in Batch 2 is done
# Row 564 in Batch 2 is done
# Row 565 in Batch 2 is done
# Row 566 in Batch 2 is done
# Row 567 in Batch 2 is done
# Row 568 in Batch 2 is done
# Row 569 in Batch 2 is done
# Row 570 in Batch 2 is done
# Row 571 in Batch 2 is done
# Row 572 in Batch 2 is done
# Row 573 in Batch 2 is done
# Row 574 in Batch 2 is done
# Row 575 in Batch 2 is done
# Row 576 in Batch 2 is done
# Row 577 in Batch 2 is done
# Row 578 in Batch 2 is done
# Row 579 in Batch 2 is done
# Row 580 in Batch 2 is done
# Row 581 in Batch 2 is done
# Row 582 in Batch 2 is done
# Row 583 in Batch 2 is done
# Row 584 in Batch 2 is done
# Row 585 in Batch 2 is done
# Row 586 in Batch 2 is done
# Row 587 in Batch 2 is done
# Row 588 in Batch 2 is done
# Row 589 in Batch 2 is done
# Row 590 in Batch 2 is done
# Row 591 in Batch 2 is done
# Row 592 in Batch 2 is done
# Row 593 in Batch 2 is done
# Row 594 in Batch 2 is done
# Row 595 in Batch 2 is done
# Row 596 in Batch 2 is done
# Row 597 in Batch 2 is done
# Row 598 in Batch 2 is done
# Row 599 in Batch 2 is done
# Row 600 in Batch 2 is done
# Row 601 in Batch 2 is done
# Row 602 in Batch 2 is done
# Row 603 in Batch 2 is done
# Row 604 in Batch 2 is done
# Row 605 in Batch 2 is done
# Row 606 in Batch 2 is done
# Row 607 in Batch 2 is done
# Row 608 in Batch 2 is done
# Row 609 in Batch 2 is done
# Row 610 in Batch 2 is done
# Row 611 in Batch 2 is done
# Row 612 in Batch 2 is done
# Row 613 in Batch 2 is done
# Row 614 in Batch 2 is done
# Row 615 in Batch 2 is done
# Row 616 in Batch 2 is done
# Row 617 in Batch 2 is done
# Row 618 in Batch 2 is done
# Row 619 in Batch 2 is done
# Row 620 in Batch 2 is done
# Row 621 in Batch 2 is done
# Row 622 in Batch 2 is done
# Row 623 in Batch 2 is done
# Row 624 in Batch 2 is done
# Row 625 in Batch 2 is done
# Row 626 in Batch 2 is done
# Row 627 in Batch 2 is done
# Row 628 in Batch 2 is done
# Row 629 in Batch 2 is done
# Row 630 in Batch 2 is done
# Row 631 in Batch 2 is done
# Row 632 in Batch 2 is done
# Row 633 in Batch 2 is done
# Row 634 in Batch 2 is done
# Row 635 in Batch 2 is done
# Row 636 in Batch 2 is done
# Row 637 in Batch 2 is done
# Row 638 in Batch 2 is done
# Row 639 in Batch 2 is done
# Row 640 in Batch 2 is done
# Row 641 in Batch 2 is done
# Row 642 in Batch 2 is done
# Row 643 in Batch 2 is done
# Row 644 in Batch 2 is done
# Row 645 in Batch 2 is done
# Row 646 in Batch 2 is done
# Row 647 in Batch 2 is done
# Row 648 in Batch 2 is done
# Row 649 in Batch 2 is done
# Row 650 in Batch 2 is done
# Row 651 in Batch 2 is done
# Row 652 in Batch 2 is done
# Row 653 in Batch 2 is done
# Row 654 in Batch 2 is done
# Row 655 in Batch 2 is done
# Row 656 in Batch 2 is done
# Row 657 in Batch 2 is done
# Row 658 in Batch 2 is done
# Row 659 in Batch 2 is done
# Row 660 in Batch 2 is done
# Row 661 in Batch 2 is done
# Row 662 in Batch 2 is done
# Row 663 in Batch 2 is done
# Row 664 in Batch 2 is done
# Row 665 in Batch 2 is done
# Row 666 in Batch 2 is done
# Row 667 in Batch 2 is done
# Row 668 in Batch 2 is done
# Row 669 in Batch 2 is done
# Row 670 in Batch 2 is done
# Row 671 in Batch 2 is done
# Row 672 in Batch 2 is done
# Row 673 in Batch 2 is done
# Row 674 in Batch 2 is done
# Row 675 in Batch 2 is done
# Row 676 in Batch 2 is done
# Row 677 in Batch 2 is done
# Row 678 in Batch 2 is done
# Row 679 in Batch 2 is done
# Row 680 in Batch 2 is done
# Row 681 in Batch 2 is done
# Row 682 in Batch 2 is done
# Row 683 in Batch 2 is done
# Row 684 in Batch 2 is done
# Row 685 in Batch 2 is done
# Row 686 in Batch 2 is done
# Row 687 in Batch 2 is done
# Row 688 in Batch 2 is done
# Row 689 in Batch 2 is done
# Row 690 in Batch 2 is done
# Row 691 in Batch 2 is done
# Row 692 in Batch 2 is done
# Row 693 in Batch 2 is done
# Row 694 in Batch 2 is done
# Row 695 in Batch 2 is done
# Row 696 in Batch 2 is done
# Row 697 in Batch 2 is done
# Row 698 in Batch 2 is done
# Row 699 in Batch 2 is done
# Row 700 in Batch 2 is done
# Row 701 in Batch 2 is done
# Row 702 in Batch 2 is done
# Row 703 in Batch 2 is done
# Row 704 in Batch 2 is done
# Row 705 in Batch 2 is done
# Row 706 in Batch 2 is done
# Row 707 in Batch 2 is done
# Row 708 in Batch 2 is done
# Row 709 in Batch 2 is done
# Row 710 in Batch 2 is done
# Row 711 in Batch 2 is done
# Row 712 in Batch 2 is done
# Row 713 in Batch 2 is done
# Row 714 in Batch 2 is done
# Row 715 in Batch 2 is done
# Row 716 in Batch 2 is done
# Row 717 in Batch 2 is done
# Row 718 in Batch 2 is done
# Row 719 in Batch 2 is done
# Row 720 in Batch 2 is done
# Row 721 in Batch 2 is done
# Row 722 in Batch 2 is done
# Row 723 in Batch 2 is done
# Row 724 in Batch 2 is done
# Row 725 in Batch 2 is done
# Row 726 in Batch 2 is done
# Row 727 in Batch 2 is done
# Row 728 in Batch 2 is done
# Row 729 in Batch 2 is done
# Row 730 in Batch 2 is done
# Row 731 in Batch 2 is done
# Row 732 in Batch 2 is done
# Row 733 in Batch 2 is done
# Row 734 in Batch 2 is done
# Row 735 in Batch 2 is done
# Row 736 in Batch 2 is done
# Row 737 in Batch 2 is done
# Row 738 in Batch 2 is done
# Row 739 in Batch 2 is done
# Row 740 in Batch 2 is done
# Row 741 in Batch 2 is done
# Row 742 in Batch 2 is done
# Row 743 in Batch 2 is done
# Row 744 in Batch 2 is done
# Row 745 in Batch 2 is done
# Row 746 in Batch 2 is done
# Row 747 in Batch 2 is done
# Row 748 in Batch 2 is done
# Row 749 in Batch 2 is done
# Row 750 in Batch 2 is done
# Row 751 in Batch 2 is done
# Row 752 in Batch 2 is done
# Row 753 in Batch 2 is done
# Row 754 in Batch 2 is done
# Row 755 in Batch 2 is done
# Row 756 in Batch 2 is done
# Row 757 in Batch 2 is done
# Row 758 in Batch 2 is done
# Row 759 in Batch 2 is done
# Row 760 in Batch 2 is done
# Row 761 in Batch 2 is done
# Row 762 in Batch 2 is done
# Row 763 in Batch 2 is done
# Row 764 in Batch 2 is done
# Row 765 in Batch 2 is done
# Row 766 in Batch 2 is done
# Row 767 in Batch 2 is done
# Row 768 in Batch 2 is done
# Row 769 in Batch 2 is done
# Row 770 in Batch 2 is done
# Row 771 in Batch 2 is done
# Row 772 in Batch 2 is done
# Row 773 in Batch 2 is done
# Row 774 in Batch 2 is done
# Row 775 in Batch 2 is done
# Row 776 in Batch 2 is done
# Row 777 in Batch 2 is done
# Row 778 in Batch 2 is done
# Row 779 in Batch 2 is done
# Row 780 in Batch 2 is done
# Row 781 in Batch 2 is done
# Row 782 in Batch 2 is done
# Row 783 in Batch 2 is done
# Row 784 in Batch 2 is done
# Row 785 in Batch 2 is done
# Row 786 in Batch 2 is done
# Row 787 in Batch 2 is done
# Row 788 in Batch 2 is done
# Row 789 in Batch 2 is done
# Row 790 in Batch 2 is done
# Row 791 in Batch 2 is done
# Row 792 in Batch 2 is done
# Row 793 in Batch 2 is done
# Row 794 in Batch 2 is done
# Row 795 in Batch 2 is done
# Row 796 in Batch 2 is done
# Row 797 in Batch 2 is done
# Row 798 in Batch 2 is done
# Row 799 in Batch 2 is done
# Row 800 in Batch 2 is done
# Row 801 in Batch 2 is done
# Row 802 in Batch 2 is done
# Row 803 in Batch 2 is done
# Row 804 in Batch 2 is done
# Row 805 in Batch 2 is done
# Row 806 in Batch 2 is done
# Row 807 in Batch 2 is done
# Row 808 in Batch 2 is done
# Row 809 in Batch 2 is done
# Row 810 in Batch 2 is done
# Row 811 in Batch 2 is done
# Row 812 in Batch 2 is done
# Row 813 in Batch 2 is done
# Row 814 in Batch 2 is done
# Row 815 in Batch 2 is done
# Row 816 in Batch 2 is done
# Row 817 in Batch 2 is done
# Row 818 in Batch 2 is done
# Row 819 in Batch 2 is done
# Row 820 in Batch 2 is done
# Row 821 in Batch 2 is done
# Row 822 in Batch 2 is done
# Row 823 in Batch 2 is done
# Row 824 in Batch 2 is done
# Row 825 in Batch 2 is done
# Row 826 in Batch 2 is done
# Row 827 in Batch 2 is done
# Row 828 in Batch 2 is done
# Row 829 in Batch 2 is done
# Row 830 in Batch 2 is done
# Row 831 in Batch 2 is done
# Row 832 in Batch 2 is done
# Row 833 in Batch 2 is done
# Row 834 in Batch 2 is done
# Row 835 in Batch 2 is done
# Row 836 in Batch 2 is done
# Row 837 in Batch 2 is done
# Row 838 in Batch 2 is done
# Row 839 in Batch 2 is done
# Row 840 in Batch 2 is done
# Row 841 in Batch 2 is done
# Row 842 in Batch 2 is done
# Row 843 in Batch 2 is done
# Row 844 in Batch 2 is done
# Row 845 in Batch 2 is done
# Row 846 in Batch 2 is done
# Row 847 in Batch 2 is done
# Row 848 in Batch 2 is done
# Row 849 in Batch 2 is done
# Row 850 in Batch 2 is done
# Row 851 in Batch 2 is done
# Row 852 in Batch 2 is done
# Row 853 in Batch 2 is done
# Row 854 in Batch 2 is done
# Row 855 in Batch 2 is done
# Row 856 in Batch 2 is done
# Row 857 in Batch 2 is done
# Row 858 in Batch 2 is done
# Row 859 in Batch 2 is done
# Row 860 in Batch 2 is done
# Row 861 in Batch 2 is done
# Row 862 in Batch 2 is done
# Row 863 in Batch 2 is done
# Row 864 in Batch 2 is done
# Row 865 in Batch 2 is done
# Row 866 in Batch 2 is done
# Row 867 in Batch 2 is done
# Row 868 in Batch 2 is done
# Row 869 in Batch 2 is done
# Row 870 in Batch 2 is done
# Row 871 in Batch 2 is done
# Row 872 in Batch 2 is done
# Row 873 in Batch 2 is done
# Row 874 in Batch 2 is done
# Row 875 in Batch 2 is done
# Row 876 in Batch 2 is done
# Row 877 in Batch 2 is done
# Row 878 in Batch 2 is done
# Row 879 in Batch 2 is done
# Row 880 in Batch 2 is done
# Row 881 in Batch 2 is done
# Row 882 in Batch 2 is done
# Row 883 in Batch 2 is done
# Row 884 in Batch 2 is done
# Row 885 in Batch 2 is done
# Row 886 in Batch 2 is done
# Row 887 in Batch 2 is done
# Row 888 in Batch 2 is done
# Row 889 in Batch 2 is done
# Row 890 in Batch 2 is done
# Row 891 in Batch 2 is done
# Row 892 in Batch 2 is done
# Row 893 in Batch 2 is done
# Row 894 in Batch 2 is done
# Row 895 in Batch 2 is done
# Row 896 in Batch 2 is done
# Row 897 in Batch 2 is done
# Row 898 in Batch 2 is done
# Row 899 in Batch 2 is done
# Row 900 in Batch 2 is done
# Row 901 in Batch 2 is done
# Row 902 in Batch 2 is done
# Row 903 in Batch 2 is done
# Row 904 in Batch 2 is done
# Row 905 in Batch 2 is done
# Row 906 in Batch 2 is done
# Row 907 in Batch 2 is done
# Row 908 in Batch 2 is done
# Row 909 in Batch 2 is done
# Row 910 in Batch 2 is done
# Row 911 in Batch 2 is done
# Row 912 in Batch 2 is done
# Row 913 in Batch 2 is done
# Row 914 in Batch 2 is done
# Row 915 in Batch 2 is done
# Row 916 in Batch 2 is done
# Row 917 in Batch 2 is done
# Row 918 in Batch 2 is done
# Row 919 in Batch 2 is done
# Row 920 in Batch 2 is done
# Row 921 in Batch 2 is done
# Row 922 in Batch 2 is done
# Row 923 in Batch 2 is done
# Row 924 in Batch 2 is done
# Row 925 in Batch 2 is done
# Row 926 in Batch 2 is done
# Row 927 in Batch 2 is done
# Row 928 in Batch 2 is done
# Row 929 in Batch 2 is done
# Row 930 in Batch 2 is done
# Row 931 in Batch 2 is done
# Row 932 in Batch 2 is done
# Row 933 in Batch 2 is done
# Row 934 in Batch 2 is done
# Row 935 in Batch 2 is done
# Row 936 in Batch 2 is done
# Row 937 in Batch 2 is done
# Row 938 in Batch 2 is done
# Row 939 in Batch 2 is done
# Row 940 in Batch 2 is done
# Row 941 in Batch 2 is done
# Row 942 in Batch 2 is done
# Row 943 in Batch 2 is done
# Row 944 in Batch 2 is done
# Row 945 in Batch 2 is done
# Row 946 in Batch 2 is done
# Row 947 in Batch 2 is done
# Row 948 in Batch 2 is done
# Row 949 in Batch 2 is done
# Row 950 in Batch 2 is done
# Row 951 in Batch 2 is done
# Row 952 in Batch 2 is done
# Row 953 in Batch 2 is done
# Row 954 in Batch 2 is done
# Row 955 in Batch 2 is done
# Row 956 in Batch 2 is done
# Row 957 in Batch 2 is done
# Row 958 in Batch 2 is done
# Row 959 in Batch 2 is done
# Row 960 in Batch 2 is done
# Row 961 in Batch 2 is done
# Row 962 in Batch 2 is done
# Row 963 in Batch 2 is done
# Row 964 in Batch 2 is done
# Row 965 in Batch 2 is done
# Row 966 in Batch 2 is done
# Row 967 in Batch 2 is done
# Row 968 in Batch 2 is done
# Row 969 in Batch 2 is done
# Row 970 in Batch 2 is done
# Row 971 in Batch 2 is done
# Row 972 in Batch 2 is done
# Row 973 in Batch 2 is done
# Row 974 in Batch 2 is done
# Row 975 in Batch 2 is done
# Row 976 in Batch 2 is done
# Row 977 in Batch 2 is done
# Row 978 in Batch 2 is done
# Row 979 in Batch 2 is done
# Row 980 in Batch 2 is done
# Row 981 in Batch 2 is done
# Row 982 in Batch 2 is done
# Row 983 in Batch 2 is done
# Row 984 in Batch 2 is done
# Row 985 in Batch 2 is done
# Row 986 in Batch 2 is done
# Row 987 in Batch 2 is done
# Row 988 in Batch 2 is done
# Row 989 in Batch 2 is done
# Row 990 in Batch 2 is done
# Row 991 in Batch 2 is done
# Row 992 in Batch 2 is done
# Row 993 in Batch 2 is done
# Row 994 in Batch 2 is done
# Row 995 in Batch 2 is done
# Row 996 in Batch 2 is done
# Row 997 in Batch 2 is done
# Row 998 in Batch 2 is done
# Row 999 in Batch 2 is done
# Row 1000 in Batch 2 is done
# Row 1001 in Batch 2 is done
# Row 1002 in Batch 2 is done
# Row 1003 in Batch 2 is done
# Row 1004 in Batch 2 is done
# Row 1005 in Batch 2 is done
# Row 1006 in Batch 2 is done
# Row 1007 in Batch 2 is done
# Row 1008 in Batch 2 is done
# Row 1009 in Batch 2 is done
# Row 1010 in Batch 2 is done
# Row 1011 in Batch 2 is done
# Row 1012 in Batch 2 is done
# Row 1013 in Batch 2 is done
# Row 1014 in Batch 2 is done
# Row 1015 in Batch 2 is done
# Row 1016 in Batch 2 is done
# Row 1017 in Batch 2 is done
# Row 1018 in Batch 2 is done
# Row 1019 in Batch 2 is done
# Row 1020 in Batch 2 is done
# Row 1021 in Batch 2 is done
# Row 1022 in Batch 2 is done
# Row 1023 in Batch 2 is done
# Row 1024 in Batch 2 is done
# Row 1025 in Batch 3 is done
# Row 1026 in Batch 3 is done
# Row 1027 in Batch 3 is done
# Row 1028 in Batch 3 is done
# Row 1029 in Batch 3 is done
# Row 1030 in Batch 3 is done
# Row 1031 in Batch 3 is done
# Row 1032 in Batch 3 is done
# Row 1033 in Batch 3 is done
# Row 1034 in Batch 3 is done
# Row 1035 in Batch 3 is done
# Row 1036 in Batch 3 is done
# Row 1037 in Batch 3 is done
# Row 1038 in Batch 3 is done
# Row 1039 in Batch 3 is done
# Row 1040 in Batch 3 is done
# Row 1041 in Batch 3 is done
# Row 1042 in Batch 3 is done
# Row 1043 in Batch 3 is done
# Row 1044 in Batch 3 is done
# Row 1045 in Batch 3 is done
# Row 1046 in Batch 3 is done
# Row 1047 in Batch 3 is done
# Row 1048 in Batch 3 is done
# Row 1049 in Batch 3 is done
# Row 1050 in Batch 3 is done
# Row 1051 in Batch 3 is done
# Row 1052 in Batch 3 is done
# Row 1053 in Batch 3 is done
# Row 1054 in Batch 3 is done
# Row 1055 in Batch 3 is done
# Row 1056 in Batch 3 is done
# Row 1057 in Batch 3 is done
# Row 1058 in Batch 3 is done
# Row 1059 in Batch 3 is done
# Row 1060 in Batch 3 is done
# Row 1061 in Batch 3 is done
# Row 1062 in Batch 3 is done
# Row 1063 in Batch 3 is done
# Row 1064 in Batch 3 is done
# Row 1065 in Batch 3 is done
# Row 1066 in Batch 3 is done
# Row 1067 in Batch 3 is done
# Row 1068 in Batch 3 is done
# Row 1069 in Batch 3 is done
# Row 1070 in Batch 3 is done
# Row 1071 in Batch 3 is done
# Row 1072 in Batch 3 is done
# Row 1073 in Batch 3 is done
# Row 1074 in Batch 3 is done
# Row 1075 in Batch 3 is done
# Row 1076 in Batch 3 is done
# Row 1077 in Batch 3 is done
# Row 1078 in Batch 3 is done
# Row 1079 in Batch 3 is done
# Row 1080 in Batch 3 is done
# Row 1081 in Batch 3 is done
# Row 1082 in Batch 3 is done
# Row 1083 in Batch 3 is done
# Row 1084 in Batch 3 is done
# Row 1085 in Batch 3 is done
# Row 1086 in Batch 3 is done
# Row 1087 in Batch 3 is done
# Row 1088 in Batch 3 is done
# Row 1089 in Batch 3 is done
# Row 1090 in Batch 3 is done
# Row 1091 in Batch 3 is done
# Row 1092 in Batch 3 is done
# Row 1093 in Batch 3 is done
# Row 1094 in Batch 3 is done
# Row 1095 in Batch 3 is done
# Row 1096 in Batch 3 is done
# Row 1097 in Batch 3 is done
# Row 1098 in Batch 3 is done
# Row 1099 in Batch 3 is done
# Row 1100 in Batch 3 is done
# Row 1101 in Batch 3 is done
# Row 1102 in Batch 3 is done
# Row 1103 in Batch 3 is done
# Row 1104 in Batch 3 is done
# Row 1105 in Batch 3 is done
# Row 1106 in Batch 3 is done
# Row 1107 in Batch 3 is done
# Row 1108 in Batch 3 is done
# Row 1109 in Batch 3 is done
# Row 1110 in Batch 3 is done
# Row 1111 in Batch 3 is done
# Row 1112 in Batch 3 is done
# Row 1113 in Batch 3 is done
# Row 1114 in Batch 3 is done
# Row 1115 in Batch 3 is done
# Row 1116 in Batch 3 is done
# Row 1117 in Batch 3 is done
# Row 1118 in Batch 3 is done
# Row 1119 in Batch 3 is done
# Row 1120 in Batch 3 is done
# Row 1121 in Batch 3 is done
# Row 1122 in Batch 3 is done
# Row 1123 in Batch 3 is done
# Row 1124 in Batch 3 is done
# Row 1125 in Batch 3 is done
# Row 1126 in Batch 3 is done
# Row 1127 in Batch 3 is done
# Row 1128 in Batch 3 is done
# Row 1129 in Batch 3 is done
# Row 1130 in Batch 3 is done
# Row 1131 in Batch 3 is done
# Row 1132 in Batch 3 is done
# Row 1133 in Batch 3 is done
# Row 1134 in Batch 3 is done
# Row 1135 in Batch 3 is done
# Row 1136 in Batch 3 is done
# Row 1137 in Batch 3 is done
# Row 1138 in Batch 3 is done
# Row 1139 in Batch 3 is done
# Row 1140 in Batch 3 is done
# Row 1141 in Batch 3 is done
# Row 1142 in Batch 3 is done
# Row 1143 in Batch 3 is done
# Row 1144 in Batch 3 is done
# Row 1145 in Batch 3 is done
# Row 1146 in Batch 3 is done
# Row 1147 in Batch 3 is done
# Row 1148 in Batch 3 is done
# Row 1149 in Batch 3 is done
# Row 1150 in Batch 3 is done
# Row 1151 in Batch 3 is done
# Row 1152 in Batch 3 is done
# Row 1153 in Batch 3 is done
# Row 1154 in Batch 3 is done
# Row 1155 in Batch 3 is done
# Row 1156 in Batch 3 is done
# Row 1157 in Batch 3 is done
# Row 1158 in Batch 3 is done
# Row 1159 in Batch 3 is done
# Row 1160 in Batch 3 is done
# Row 1161 in Batch 3 is done
# Row 1162 in Batch 3 is done
# Row 1163 in Batch 3 is done
# Row 1164 in Batch 3 is done
# Row 1165 in Batch 3 is done
# Row 1166 in Batch 3 is done
# Row 1167 in Batch 3 is done
# Row 1168 in Batch 3 is done
# Row 1169 in Batch 3 is done
# Row 1170 in Batch 3 is done
# Row 1171 in Batch 3 is done
# Row 1172 in Batch 3 is done
# Row 1173 in Batch 3 is done
# Row 1174 in Batch 3 is done
# Row 1175 in Batch 3 is done
# Row 1176 in Batch 3 is done
# Row 1177 in Batch 3 is done
# Row 1178 in Batch 3 is done
# Row 1179 in Batch 3 is done
# Row 1180 in Batch 3 is done
# Row 1181 in Batch 3 is done
# Row 1182 in Batch 3 is done
# Row 1183 in Batch 3 is done
# Row 1184 in Batch 3 is done
# Row 1185 in Batch 3 is done
# Row 1186 in Batch 3 is done
# Row 1187 in Batch 3 is done
# Row 1188 in Batch 3 is done
# Row 1189 in Batch 3 is done
# Row 1190 in Batch 3 is done
# Row 1191 in Batch 3 is done
# Row 1192 in Batch 3 is done
# Row 1193 in Batch 3 is done
# Row 1194 in Batch 3 is done
# Row 1195 in Batch 3 is done
# Row 1196 in Batch 3 is done
# Row 1197 in Batch 3 is done
# Row 1198 in Batch 3 is done
# Row 1199 in Batch 3 is done
# Row 1200 in Batch 3 is done
# Row 1201 in Batch 3 is done
# Row 1202 in Batch 3 is done
# Row 1203 in Batch 3 is done
# Row 1204 in Batch 3 is done
# Row 1205 in Batch 3 is done
# Row 1206 in Batch 3 is done
# Row 1207 in Batch 3 is done
# Row 1208 in Batch 3 is done
# Row 1209 in Batch 3 is done
# Row 1210 in Batch 3 is done
# Row 1211 in Batch 3 is done
# Row 1212 in Batch 3 is done
# Row 1213 in Batch 3 is done
# Row 1214 in Batch 3 is done
# Row 1215 in Batch 3 is done
# Row 1216 in Batch 3 is done
# Row 1217 in Batch 3 is done
# Row 1218 in Batch 3 is done
# Row 1219 in Batch 3 is done
# Row 1220 in Batch 3 is done
# Row 1221 in Batch 3 is done
# Row 1222 in Batch 3 is done
# Row 1223 in Batch 3 is done
# Row 1224 in Batch 3 is done
# Row 1225 in Batch 3 is done
# Row 1226 in Batch 3 is done
# Row 1227 in Batch 3 is done
# Row 1228 in Batch 3 is done
# Row 1229 in Batch 3 is done
# Row 1230 in Batch 3 is done
# Row 1231 in Batch 3 is done
# Row 1232 in Batch 3 is done
# Row 1233 in Batch 3 is done
# Row 1234 in Batch 3 is done
# Row 1235 in Batch 3 is done
# Row 1236 in Batch 3 is done
# Row 1237 in Batch 3 is done
# Row 1238 in Batch 3 is done
# Row 1239 in Batch 3 is done
# Row 1240 in Batch 3 is done
# Row 1241 in Batch 3 is done
# Row 1242 in Batch 3 is done
# Row 1243 in Batch 3 is done
# Row 1244 in Batch 3 is done
# Row 1245 in Batch 3 is done
# Row 1246 in Batch 3 is done
# Row 1247 in Batch 3 is done
# Row 1248 in Batch 3 is done
# Row 1249 in Batch 3 is done
# Row 1250 in Batch 3 is done
# Row 1251 in Batch 3 is done
# Row 1252 in Batch 3 is done
# Row 1253 in Batch 3 is done
# Row 1254 in Batch 3 is done
# Row 1255 in Batch 3 is done
# Row 1256 in Batch 3 is done
# Row 1257 in Batch 3 is done
# Row 1258 in Batch 3 is done
# Row 1259 in Batch 3 is done
# Row 1260 in Batch 3 is done
# Row 1261 in Batch 3 is done
# Row 1262 in Batch 3 is done
# Row 1263 in Batch 3 is done
# Row 1264 in Batch 3 is done
# Row 1265 in Batch 3 is done
# Row 1266 in Batch 3 is done
# Row 1267 in Batch 3 is done
# Row 1268 in Batch 3 is done
# Row 1269 in Batch 3 is done
# Row 1270 in Batch 3 is done
# Row 1271 in Batch 3 is done
# Row 1272 in Batch 3 is done
# Row 1273 in Batch 3 is done
# Row 1274 in Batch 3 is done
# Row 1275 in Batch 3 is done
# Row 1276 in Batch 3 is done
# Row 1277 in Batch 3 is done
# Row 1278 in Batch 3 is done
# Row 1279 in Batch 3 is done
# Row 1280 in Batch 3 is done
# Row 1281 in Batch 3 is done
# Row 1282 in Batch 3 is done
# Row 1283 in Batch 3 is done
# Row 1284 in Batch 3 is done
# Row 1285 in Batch 3 is done
# Row 1286 in Batch 3 is done
# Row 1287 in Batch 3 is done
# Row 1288 in Batch 3 is done
# Row 1289 in Batch 3 is done
# Row 1290 in Batch 3 is done
# Row 1291 in Batch 3 is done
# Row 1292 in Batch 3 is done
# Row 1293 in Batch 3 is done
# Row 1294 in Batch 3 is done
# Row 1295 in Batch 3 is done
# Row 1296 in Batch 3 is done
# Row 1297 in Batch 3 is done
# Row 1298 in Batch 3 is done
# Row 1299 in Batch 3 is done
# Row 1300 in Batch 3 is done
# Row 1301 in Batch 3 is done
# Row 1302 in Batch 3 is done
# Row 1303 in Batch 3 is done
# Row 1304 in Batch 3 is done
# Row 1305 in Batch 3 is done
# Row 1306 in Batch 3 is done
# Row 1307 in Batch 3 is done
# Row 1308 in Batch 3 is done
# Row 1309 in Batch 3 is done
# Row 1310 in Batch 3 is done
# Row 1311 in Batch 3 is done
# Row 1312 in Batch 3 is done
# Row 1313 in Batch 3 is done
# Row 1314 in Batch 3 is done
# Row 1315 in Batch 3 is done
# Row 1316 in Batch 3 is done
# Row 1317 in Batch 3 is done
# Row 1318 in Batch 3 is done
# Row 1319 in Batch 3 is done
# Row 1320 in Batch 3 is done
# Row 1321 in Batch 3 is done
# Row 1322 in Batch 3 is done
# Row 1323 in Batch 3 is done
# Row 1324 in Batch 3 is done
# Row 1325 in Batch 3 is done
# Row 1326 in Batch 3 is done
# Row 1327 in Batch 3 is done
# Row 1328 in Batch 3 is done
# Row 1329 in Batch 3 is done
# Row 1330 in Batch 3 is done
# Row 1331 in Batch 3 is done
# Row 1332 in Batch 3 is done
# Row 1333 in Batch 3 is done
# Row 1334 in Batch 3 is done
# Row 1335 in Batch 3 is done
# Row 1336 in Batch 3 is done
# Row 1337 in Batch 3 is done
# Row 1338 in Batch 3 is done
# Row 1339 in Batch 3 is done
# Row 1340 in Batch 3 is done
# Row 1341 in Batch 3 is done
# Row 1342 in Batch 3 is done
# Row 1343 in Batch 3 is done
# Row 1344 in Batch 3 is done
# Row 1345 in Batch 3 is done
# Row 1346 in Batch 3 is done
# Row 1347 in Batch 3 is done
# Row 1348 in Batch 3 is done
# Row 1349 in Batch 3 is done
# Row 1350 in Batch 3 is done
# Row 1351 in Batch 3 is done
# Row 1352 in Batch 3 is done
# Row 1353 in Batch 3 is done
# Row 1354 in Batch 3 is done
# Row 1355 in Batch 3 is done
# Row 1356 in Batch 3 is done
# Row 1357 in Batch 3 is done
# Row 1358 in Batch 3 is done
# Row 1359 in Batch 3 is done
# Row 1360 in Batch 3 is done
# Row 1361 in Batch 3 is done
# Row 1362 in Batch 3 is done
# Row 1363 in Batch 3 is done
# Row 1364 in Batch 3 is done
# Row 1365 in Batch 3 is done
# Row 1366 in Batch 3 is done
# Row 1367 in Batch 3 is done
# Row 1368 in Batch 3 is done
# Row 1369 in Batch 3 is done
# Row 1370 in Batch 3 is done
# Row 1371 in Batch 3 is done
# Row 1372 in Batch 3 is done
# Row 1373 in Batch 3 is done
# Row 1374 in Batch 3 is done
# Row 1375 in Batch 3 is done
# Row 1376 in Batch 3 is done
# Row 1377 in Batch 3 is done
# Row 1378 in Batch 3 is done
# Row 1379 in Batch 3 is done
# Row 1380 in Batch 3 is done
# Row 1381 in Batch 3 is done
# Row 1382 in Batch 3 is done
# Row 1383 in Batch 3 is done
# Row 1384 in Batch 3 is done
# Row 1385 in Batch 3 is done
# Row 1386 in Batch 3 is done
# Row 1387 in Batch 3 is done
# Row 1388 in Batch 3 is done
# Row 1389 in Batch 3 is done
# Row 1390 in Batch 3 is done
# Row 1391 in Batch 3 is done
# Row 1392 in Batch 3 is done
# Row 1393 in Batch 3 is done
# Row 1394 in Batch 3 is done
# Row 1395 in Batch 3 is done
# Row 1396 in Batch 3 is done
# Row 1397 in Batch 3 is done
# Row 1398 in Batch 3 is done
# Row 1399 in Batch 3 is done
# Row 1400 in Batch 3 is done
# Row 1401 in Batch 3 is done
# Row 1402 in Batch 3 is done
# Row 1403 in Batch 3 is done
# Row 1404 in Batch 3 is done
# Row 1405 in Batch 3 is done
# Row 1406 in Batch 3 is done
# Row 1407 in Batch 3 is done
# Row 1408 in Batch 3 is done
# Row 1409 in Batch 3 is done
# Row 1410 in Batch 3 is done
# Row 1411 in Batch 3 is done
# Row 1412 in Batch 3 is done
# Row 1413 in Batch 3 is done
# Row 1414 in Batch 3 is done
# Row 1415 in Batch 3 is done
# Row 1416 in Batch 3 is done
# Row 1417 in Batch 3 is done
# Row 1418 in Batch 3 is done
# Row 1419 in Batch 3 is done
# Row 1420 in Batch 3 is done
# Row 1421 in Batch 3 is done
# Row 1422 in Batch 3 is done
# Row 1423 in Batch 3 is done
# Row 1424 in Batch 3 is done
# Row 1425 in Batch 3 is done
# Row 1426 in Batch 3 is done
# Row 1427 in Batch 3 is done
# Row 1428 in Batch 3 is done
# Row 1429 in Batch 3 is done
# Row 1430 in Batch 3 is done
# Row 1431 in Batch 3 is done
# Row 1432 in Batch 3 is done
# Row 1433 in Batch 3 is done
# Row 1434 in Batch 3 is done
# Row 1435 in Batch 3 is done
# Row 1436 in Batch 3 is done
# Row 1437 in Batch 3 is done
# Row 1438 in Batch 3 is done
# Row 1439 in Batch 3 is done
# Row 1440 in Batch 3 is done
# Row 1441 in Batch 3 is done
# Row 1442 in Batch 3 is done
# Row 1443 in Batch 3 is done
# Row 1444 in Batch 3 is done
# Row 1445 in Batch 3 is done
# Row 1446 in Batch 3 is done
# Row 1447 in Batch 3 is done
# Row 1448 in Batch 3 is done
# Row 1449 in Batch 3 is done
# Row 1450 in Batch 3 is done
# Row 1451 in Batch 3 is done
# Row 1452 in Batch 3 is done
# Row 1453 in Batch 3 is done
# Row 1454 in Batch 3 is done
# Row 1455 in Batch 3 is done
# Row 1456 in Batch 3 is done
# Row 1457 in Batch 3 is done
# Row 1458 in Batch 3 is done
# Row 1459 in Batch 3 is done
# Row 1460 in Batch 3 is done
# Row 1461 in Batch 3 is done
# Row 1462 in Batch 3 is done
# Row 1463 in Batch 3 is done
# Row 1464 in Batch 3 is done
# Row 1465 in Batch 3 is done
# Row 1466 in Batch 3 is done
# Row 1467 in Batch 3 is done
# Row 1468 in Batch 3 is done
# Row 1469 in Batch 3 is done
# Row 1470 in Batch 3 is done
# Row 1471 in Batch 3 is done
# Row 1472 in Batch 3 is done
# Row 1473 in Batch 3 is done
# Row 1474 in Batch 3 is done
# Row 1475 in Batch 3 is done
# Row 1476 in Batch 3 is done
# Row 1477 in Batch 3 is done
# Row 1478 in Batch 3 is done
# Row 1479 in Batch 3 is done
# Row 1480 in Batch 3 is done
# Row 1481 in Batch 3 is done
# Row 1482 in Batch 3 is done
# Row 1483 in Batch 3 is done
# Row 1484 in Batch 3 is done
# Row 1485 in Batch 3 is done
# Row 1486 in Batch 3 is done
# Row 1487 in Batch 3 is done
# Row 1488 in Batch 3 is done
# Row 1489 in Batch 3 is done
# Row 1490 in Batch 3 is done
# Row 1491 in Batch 3 is done
# Row 1492 in Batch 3 is done
# Row 1493 in Batch 3 is done
# Row 1494 in Batch 3 is done
# Row 1495 in Batch 3 is done
# Row 1496 in Batch 3 is done
# Row 1497 in Batch 3 is done
# Row 1498 in Batch 3 is done
# Row 1499 in Batch 3 is done
# Row 1500 in Batch 3 is done
# Row 1501 in Batch 3 is done
# Row 1502 in Batch 3 is done
# Row 1503 in Batch 3 is done
# Row 1504 in Batch 3 is done
# Row 1505 in Batch 3 is done
# Row 1506 in Batch 3 is done
# Row 1507 in Batch 3 is done
# Row 1508 in Batch 3 is done
# Row 1509 in Batch 3 is done
# Row 1510 in Batch 3 is done
# Row 1511 in Batch 3 is done
# Row 1512 in Batch 3 is done
# Row 1513 in Batch 3 is done
# Row 1514 in Batch 3 is done
# Row 1515 in Batch 3 is done
# Row 1516 in Batch 3 is done
# Row 1517 in Batch 3 is done
# Row 1518 in Batch 3 is done
# Row 1519 in Batch 3 is done
# Row 1520 in Batch 3 is done
# Row 1521 in Batch 3 is done
# Row 1522 in Batch 3 is done
# Row 1523 in Batch 3 is done
# Row 1524 in Batch 3 is done
# Row 1525 in Batch 3 is done
# Row 1526 in Batch 3 is done
# Row 1527 in Batch 3 is done
# Row 1528 in Batch 3 is done
# Row 1529 in Batch 3 is done
# Row 1530 in Batch 3 is done
# Row 1531 in Batch 3 is done
# Row 1532 in Batch 3 is done
# Row 1533 in Batch 3 is done
# Row 1534 in Batch 3 is done
# Row 1535 in Batch 3 is done
# Row 1536 in Batch 3 is done
# Row 1537 in Batch 4 is done
# Row 1538 in Batch 4 is done
# Row 1539 in Batch 4 is done
# Row 1540 in Batch 4 is done
# Row 1541 in Batch 4 is done
# Row 1542 in Batch 4 is done
# Row 1543 in Batch 4 is done
# Row 1544 in Batch 4 is done
# Row 1545 in Batch 4 is done
# Row 1546 in Batch 4 is done
# Row 1547 in Batch 4 is done
# Row 1548 in Batch 4 is done
# Row 1549 in Batch 4 is done
# Row 1550 in Batch 4 is done
# Row 1551 in Batch 4 is done
# Row 1552 in Batch 4 is done
# Row 1553 in Batch 4 is done
# Row 1554 in Batch 4 is done
# Row 1555 in Batch 4 is done
# Row 1556 in Batch 4 is done
# Row 1557 in Batch 4 is done
# Row 1558 in Batch 4 is done
# Row 1559 in Batch 4 is done
# Row 1560 in Batch 4 is done
# Row 1561 in Batch 4 is done
# Row 1562 in Batch 4 is done
# Row 1563 in Batch 4 is done
# Row 1564 in Batch 4 is done
# Row 1565 in Batch 4 is done
# Row 1566 in Batch 4 is done
# Row 1567 in Batch 4 is done
# Row 1568 in Batch 4 is done
# Row 1569 in Batch 4 is done
# Row 1570 in Batch 4 is done
# Row 1571 in Batch 4 is done
# Row 1572 in Batch 4 is done
# Row 1573 in Batch 4 is done
# Row 1574 in Batch 4 is done
# Row 1575 in Batch 4 is done
# Row 1576 in Batch 4 is done
# Row 1577 in Batch 4 is done
# Row 1578 in Batch 4 is done
# Row 1579 in Batch 4 is done
# Row 1580 in Batch 4 is done
# Row 1581 in Batch 4 is done
# Row 1582 in Batch 4 is done
# Row 1583 in Batch 4 is done
# Row 1584 in Batch 4 is done
# Row 1585 in Batch 4 is done
# Row 1586 in Batch 4 is done
# Row 1587 in Batch 4 is done
# Row 1588 in Batch 4 is done
# Row 1589 in Batch 4 is done
# Row 1590 in Batch 4 is done
# Row 1591 in Batch 4 is done
# Row 1592 in Batch 4 is done
# Row 1593 in Batch 4 is done
# Row 1594 in Batch 4 is done
# Row 1595 in Batch 4 is done
# Row 1596 in Batch 4 is done
# Row 1597 in Batch 4 is done
# Row 1598 in Batch 4 is done
# Row 1599 in Batch 4 is done
# Row 1600 in Batch 4 is done
# Row 1601 in Batch 4 is done
# Row 1602 in Batch 4 is done
# Row 1603 in Batch 4 is done
# Row 1604 in Batch 4 is done
# Row 1605 in Batch 4 is done
# Row 1606 in Batch 4 is done
# Row 1607 in Batch 4 is done
# Row 1608 in Batch 4 is done
# Row 1609 in Batch 4 is done
# Row 1610 in Batch 4 is done
# Row 1611 in Batch 4 is done
# Row 1612 in Batch 4 is done
# Row 1613 in Batch 4 is done
# Row 1614 in Batch 4 is done
# Row 1615 in Batch 4 is done
# Row 1616 in Batch 4 is done
# Row 1617 in Batch 4 is done
# Row 1618 in Batch 4 is done
# Row 1619 in Batch 4 is done
# Row 1620 in Batch 4 is done
# Row 1621 in Batch 4 is done
# Row 1622 in Batch 4 is done
# Row 1623 in Batch 4 is done
# Row 1624 in Batch 4 is done
# Row 1625 in Batch 4 is done
# Row 1626 in Batch 4 is done
# Row 1627 in Batch 4 is done
# Row 1628 in Batch 4 is done
# Row 1629 in Batch 4 is done
# Row 1630 in Batch 4 is done
# Row 1631 in Batch 4 is done
# Row 1632 in Batch 4 is done
# Row 1633 in Batch 4 is done
# Row 1634 in Batch 4 is done
# Row 1635 in Batch 4 is done
# Row 1636 in Batch 4 is done
# Row 1637 in Batch 4 is done
# Row 1638 in Batch 4 is done
# Row 1639 in Batch 4 is done
# Row 1640 in Batch 4 is done
# Row 1641 in Batch 4 is done
# Row 1642 in Batch 4 is done
# Row 1643 in Batch 4 is done
# Row 1644 in Batch 4 is done
# Row 1645 in Batch 4 is done
# Row 1646 in Batch 4 is done
# Row 1647 in Batch 4 is done
# Row 1648 in Batch 4 is done
# Row 1649 in Batch 4 is done
# Row 1650 in Batch 4 is done
# Row 1651 in Batch 4 is done
# Row 1652 in Batch 4 is done
# Row 1653 in Batch 4 is done
# Row 1654 in Batch 4 is done
# Row 1655 in Batch 4 is done
# Row 1656 in Batch 4 is done
# Row 1657 in Batch 4 is done
# Row 1658 in Batch 4 is done
# Row 1659 in Batch 4 is done
# Row 1660 in Batch 4 is done
# Row 1661 in Batch 4 is done
# Row 1662 in Batch 4 is done
# Row 1663 in Batch 4 is done
# Row 1664 in Batch 4 is done
# Row 1665 in Batch 4 is done
# Row 1666 in Batch 4 is done
# Row 1667 in Batch 4 is done
# Row 1668 in Batch 4 is done
# Row 1669 in Batch 4 is done
# Row 1670 in Batch 4 is done
# Row 1671 in Batch 4 is done
# Row 1672 in Batch 4 is done
# Row 1673 in Batch 4 is done
# Row 1674 in Batch 4 is done
# Row 1675 in Batch 4 is done
# Row 1676 in Batch 4 is done
# Row 1677 in Batch 4 is done
# Row 1678 in Batch 4 is done
# Row 1679 in Batch 4 is done
# Row 1680 in Batch 4 is done
# Row 1681 in Batch 4 is done
# Row 1682 in Batch 4 is done
# Row 1683 in Batch 4 is done
# Row 1684 in Batch 4 is done
# Row 1685 in Batch 4 is done
# Row 1686 in Batch 4 is done
# Row 1687 in Batch 4 is done
# Row 1688 in Batch 4 is done
# Row 1689 in Batch 4 is done
# Row 1690 in Batch 4 is done
# Row 1691 in Batch 4 is done
# Row 1692 in Batch 4 is done
# Row 1693 in Batch 4 is done
# Row 1694 in Batch 4 is done
# Row 1695 in Batch 4 is done
# Row 1696 in Batch 4 is done
# Row 1697 in Batch 4 is done
# Row 1698 in Batch 4 is done
# Row 1699 in Batch 4 is done
# Row 1700 in Batch 4 is done
# Row 1701 in Batch 4 is done
# Row 1702 in Batch 4 is done
# Row 1703 in Batch 4 is done
# Row 1704 in Batch 4 is done
# Row 1705 in Batch 4 is done
# Row 1706 in Batch 4 is done
# Row 1707 in Batch 4 is done
# Row 1708 in Batch 4 is done
# Row 1709 in Batch 4 is done
# Row 1710 in Batch 4 is done
# Row 1711 in Batch 4 is done
# Row 1712 in Batch 4 is done
# Row 1713 in Batch 4 is done
# Row 1714 in Batch 4 is done
# Row 1715 in Batch 4 is done
# Row 1716 in Batch 4 is done
# Row 1717 in Batch 4 is done
# Row 1718 in Batch 4 is done
# Row 1719 in Batch 4 is done
# Row 1720 in Batch 4 is done
# Row 1721 in Batch 4 is done
# Row 1722 in Batch 4 is done
# Row 1723 in Batch 4 is done
# Row 1724 in Batch 4 is done
# Row 1725 in Batch 4 is done
# Row 1726 in Batch 4 is done
# Row 1727 in Batch 4 is done
# Row 1728 in Batch 4 is done
# Row 1729 in Batch 4 is done
# Row 1730 in Batch 4 is done
# Row 1731 in Batch 4 is done
# Row 1732 in Batch 4 is done
# Row 1733 in Batch 4 is done
# Row 1734 in Batch 4 is done
# Row 1735 in Batch 4 is done
# Row 1736 in Batch 4 is done
# Row 1737 in Batch 4 is done
# Row 1738 in Batch 4 is done
# Row 1739 in Batch 4 is done
# Row 1740 in Batch 4 is done
# Row 1741 in Batch 4 is done
# Row 1742 in Batch 4 is done
# Row 1743 in Batch 4 is done
# Row 1744 in Batch 4 is done
# Row 1745 in Batch 4 is done
# Row 1746 in Batch 4 is done
# Row 1747 in Batch 4 is done
# Row 1748 in Batch 4 is done
# Row 1749 in Batch 4 is done
# Row 1750 in Batch 4 is done
# Row 1751 in Batch 4 is done
# Row 1752 in Batch 4 is done
# Row 1753 in Batch 4 is done
# ...
# Row 10476 in Batch 21 is done
# Row 10477 in Batch 21 is done
# Row 10478 in Batch 21 is done
# Row 10479 in Batch 21 is done
# Row 10480 in Batch 21 is done
# Row 10481 in Batch 21 is done
# Row 10482 in Batch 21 is done
# Row 10483 in Batch 21 is done
# Row 10484 in Batch 21 is done
# Row 10485 in Batch 21 is done
# Row 10486 in Batch 21 is done
# Row 10487 in Batch 21 is done
# Row 10488 in Batch 21 is done
# Row 10489 in Batch 21 is done
# Row 10490 in Batch 21 is done
# Row 10491 in Batch 21 is done
# Row 10492 in Batch 21 is done
# Row 10493 in Batch 21 is done
# Row 10494 in Batch 21 is done
# Row 10495 in Batch 21 is done
# Row 10496 in Batch 21 is done
# Row 10497 in Batch 21 is done
# Row 10498 in Batch 21 is done
# Row 10499 in Batch 21 is done
# Row 10500 in Batch 21 is done
# Row 10501 in Batch 21 is done
# Row 10502 in Batch 21 is done
# Row 10503 in Batch 21 is done
# Row 10504 in Batch 21 is done
# Row 10505 in Batch 21 is done
# Row 10506 in Batch 21 is done
# Row 10507 in Batch 21 is done
# Row 10508 in Batch 21 is done
# Row 10509 in Batch 21 is done
# Row 10510 in Batch 21 is done
# Row 10511 in Batch 21 is done
# Row 10512 in Batch 21 is done
# Row 10513 in Batch 21 is done
# Row 10514 in Batch 21 is done
# Row 10515 in Batch 21 is done
# Row 10516 in Batch 21 is done
# Row 10517 in Batch 21 is done
# Row 10518 in Batch 21 is done
# Row 10519 in Batch 21 is done
# Row 10520 in Batch 21 is done
# Row 10521 in Batch 21 is done
# Row 10522 in Batch 21 is done
# Row 10523 in Batch 21 is done
# Row 10524 in Batch 21 is done
# Row 10525 in Batch 21 is done
# Row 10526 in Batch 21 is done
# Row 10527 in Batch 21 is done
# Row 10528 in Batch 21 is done
# Row 10529 in Batch 21 is done
# Row 10530 in Batch 21 is done
# Row 10531 in Batch 21 is done
# Row 10532 in Batch 21 is done
# Row 10533 in Batch 21 is done
# Row 10534 in Batch 21 is done
# Row 10535 in Batch 21 is done
# Row 10536 in Batch 21 is done
# Row 10537 in Batch 21 is done
# Row 10538 in Batch 21 is done
# Row 10539 in Batch 21 is done
# Row 10540 in Batch 21 is done
# Row 10541 in Batch 21 is done
# Row 10542 in Batch 21 is done
# Row 10543 in Batch 21 is done
# Row 10544 in Batch 21 is done
# Row 10545 in Batch 21 is done
# Row 10546 in Batch 21 is done
# Row 10547 in Batch 21 is done
# Row 10548 in Batch 21 is done
# Row 10549 in Batch 21 is done
# Row 10550 in Batch 21 is done
# Row 10551 in Batch 21 is done
# Row 10552 in Batch 21 is done
# Row 10553 in Batch 21 is done
# Row 10554 in Batch 21 is done
# Row 10555 in Batch 21 is done
# Row 10556 in Batch 21 is done
# Row 10557 in Batch 21 is done
# Row 10558 in Batch 21 is done
# Row 10559 in Batch 21 is done
# Row 10560 in Batch 21 is done
# Row 10561 in Batch 21 is done
# Row 10562 in Batch 21 is done
# Row 10563 in Batch 21 is done
# Row 10564 in Batch 21 is done
# Row 10565 in Batch 21 is done
# Row 10566 in Batch 21 is done
# Row 10567 in Batch 21 is done
# Row 10568 in Batch 21 is done
# Row 10569 in Batch 21 is done
# Row 10570 in Batch 21 is done
# Row 10571 in Batch 21 is done
# Row 10572 in Batch 21 is done
# Row 10573 in Batch 21 is done
# Row 10574 in Batch 21 is done
# Row 10575 in Batch 21 is done
# Row 10576 in Batch 21 is done
# Row 10577 in Batch 21 is done
# Row 10578 in Batch 21 is done
# Row 10579 in Batch 21 is done
# Row 10580 in Batch 21 is done
# Row 10581 in Batch 21 is done
# Row 10582 in Batch 21 is done
# Row 10583 in Batch 21 is done
# Row 10584 in Batch 21 is done
# Row 10585 in Batch 21 is done
# Row 10586 in Batch 21 is done
# Row 10587 in Batch 21 is done
# Row 10588 in Batch 21 is done
# Row 10589 in Batch 21 is done
# Row 10590 in Batch 21 is done
# Row 10591 in Batch 21 is done
# Row 10592 in Batch 21 is done
# Row 10593 in Batch 21 is done
# Row 10594 in Batch 21 is done
# Row 10595 in Batch 21 is done
# Row 10596 in Batch 21 is done
# Row 10597 in Batch 21 is done
# Row 10598 in Batch 21 is done
# Row 10599 in Batch 21 is done
# Row 10600 in Batch 21 is done
# Row 10601 in Batch 21 is done
# Row 10602 in Batch 21 is done
# Row 10603 in Batch 21 is done
# Row 10604 in Batch 21 is done
# Row 10605 in Batch 21 is done
# Row 10606 in Batch 21 is done
# Row 10607 in Batch 21 is done
# Row 10608 in Batch 21 is done
# Row 10609 in Batch 21 is done
# Row 10610 in Batch 21 is done
# Row 10611 in Batch 21 is done
# Row 10612 in Batch 21 is done
# Row 10613 in Batch 21 is done
# Row 10614 in Batch 21 is done
# Row 10615 in Batch 21 is done
# Row 10616 in Batch 21 is done
# Row 10617 in Batch 21 is done
# Row 10618 in Batch 21 is done
# Row 10619 in Batch 21 is done
# Row 10620 in Batch 21 is done
# Row 10621 in Batch 21 is done
# Row 10622 in Batch 21 is done
# Row 10623 in Batch 21 is done
# Row 10624 in Batch 21 is done
# Row 10625 in Batch 21 is done
# Row 10626 in Batch 21 is done
# Row 10627 in Batch 21 is done
# Row 10628 in Batch 21 is done
# Row 10629 in Batch 21 is done
# Row 10630 in Batch 21 is done
# Row 10631 in Batch 21 is done
# Row 10632 in Batch 21 is done
# Row 10633 in Batch 21 is done
# Row 10634 in Batch 21 is done
# Row 10635 in Batch 21 is done
# Row 10636 in Batch 21 is done
# Row 10637 in Batch 21 is done
# Row 10638 in Batch 21 is done
# Row 10639 in Batch 21 is done
# Row 10640 in Batch 21 is done
# Row 10641 in Batch 21 is done
# Row 10642 in Batch 21 is done
# Row 10643 in Batch 21 is done
# Row 10644 in Batch 21 is done
# Row 10645 in Batch 21 is done
# Row 10646 in Batch 21 is done
# Row 10647 in Batch 21 is done
# Row 10648 in Batch 21 is done
# Row 10649 in Batch 21 is done
# Row 10650 in Batch 21 is done
# Row 10651 in Batch 21 is done
# Row 10652 in Batch 21 is done
# Row 10653 in Batch 21 is done
# Row 10654 in Batch 21 is done
# Row 10655 in Batch 21 is done
# Row 10656 in Batch 21 is done
# Row 10657 in Batch 21 is done
# Row 10658 in Batch 21 is done
# Row 10659 in Batch 21 is done
# Row 10660 in Batch 21 is done
# Row 10661 in Batch 21 is done
# Row 10662 in Batch 21 is done
# Row 10663 in Batch 21 is done
# Row 10664 in Batch 21 is done
# Row 10665 in Batch 21 is done
# Row 10666 in Batch 21 is done
# Row 10667 in Batch 21 is done
# Row 10668 in Batch 21 is done
# Row 10669 in Batch 21 is done
# Row 10670 in Batch 21 is done
# Row 10671 in Batch 21 is done
# Row 10672 in Batch 21 is done
# Row 10673 in Batch 21 is done
# Row 10674 in Batch 21 is done
# Row 10675 in Batch 21 is done
# Row 10676 in Batch 21 is done
# Row 10677 in Batch 21 is done
# Row 10678 in Batch 21 is done
# Row 10679 in Batch 21 is done
# Row 10680 in Batch 21 is done
# Row 10681 in Batch 21 is done
# Row 10682 in Batch 21 is done
# Row 10683 in Batch 21 is done
# Row 10684 in Batch 21 is done
# Row 10685 in Batch 21 is done
# Row 10686 in Batch 21 is done
# Row 10687 in Batch 21 is done
# Row 10688 in Batch 21 is done
# Row 10689 in Batch 21 is done
# Row 10690 in Batch 21 is done
# Row 10691 in Batch 21 is done
# Row 10692 in Batch 21 is done
# Row 10693 in Batch 21 is done
# Row 10694 in Batch 21 is done
# Row 10695 in Batch 21 is done
# Row 10696 in Batch 21 is done
# Row 10697 in Batch 21 is done
# Row 10698 in Batch 21 is done
# Row 10699 in Batch 21 is done
# Row 10700 in Batch 21 is done
# Row 10701 in Batch 21 is done
# Row 10702 in Batch 21 is done
# Row 10703 in Batch 21 is done
# Row 10704 in Batch 21 is done
# Row 10705 in Batch 21 is done
# Row 10706 in Batch 21 is done
# Row 10707 in Batch 21 is done
# Row 10708 in Batch 21 is done
# Row 10709 in Batch 21 is done
# Row 10710 in Batch 21 is done
# Row 10711 in Batch 21 is done
# Row 10712 in Batch 21 is done
# Row 10713 in Batch 21 is done
# Row 10714 in Batch 21 is done
# Row 10715 in Batch 21 is done
# Row 10716 in Batch 21 is done
# Row 10717 in Batch 21 is done
# Row 10718 in Batch 21 is done
# Row 10719 in Batch 21 is done
# Row 10720 in Batch 21 is done
# Row 10721 in Batch 21 is done
# Row 10722 in Batch 21 is done
# Row 10723 in Batch 21 is done
# Row 10724 in Batch 21 is done
# Row 10725 in Batch 21 is done
# Row 10726 in Batch 21 is done
# Row 10727 in Batch 21 is done
# Row 10728 in Batch 21 is done
# Row 10729 in Batch 21 is done
# Row 10730 in Batch 21 is done
# Row 10731 in Batch 21 is done
# Row 10732 in Batch 21 is done
# Row 10733 in Batch 21 is done
# Row 10734 in Batch 21 is done
# Row 10735 in Batch 21 is done
# Row 10736 in Batch 21 is done
# Row 10737 in Batch 21 is done
# Row 10738 in Batch 21 is done
# Row 10739 in Batch 21 is done
# Row 10740 in Batch 21 is done
# Row 10741 in Batch 21 is done
# Row 10742 in Batch 21 is done
# Row 10743 in Batch 21 is done
# Row 10744 in Batch 21 is done
# Row 10745 in Batch 21 is done
# Row 10746 in Batch 21 is done
# Row 10747 in Batch 21 is done
# Row 10748 in Batch 21 is done
# Row 10749 in Batch 21 is done
# Row 10750 in Batch 21 is done
# Row 10751 in Batch 21 is done
# Row 10752 in Batch 21 is done
# Row 10753 in Batch 22 is done
# Row 10754 in Batch 22 is done
# Row 10755 in Batch 22 is done
# Row 10756 in Batch 22 is done
# Row 10757 in Batch 22 is done
# Row 10758 in Batch 22 is done
# Row 10759 in Batch 22 is done
# Row 10760 in Batch 22 is done
# Row 10761 in Batch 22 is done
# Row 10762 in Batch 22 is done
# Row 10763 in Batch 22 is done
# Row 10764 in Batch 22 is done
# Row 10765 in Batch 22 is done
# Row 10766 in Batch 22 is done
# Row 10767 in Batch 22 is done
# Row 10768 in Batch 22 is done
# Row 10769 in Batch 22 is done
# Row 10770 in Batch 22 is done
# Row 10771 in Batch 22 is done
# Row 10772 in Batch 22 is done
# Row 10773 in Batch 22 is done
# Row 10774 in Batch 22 is done
# Row 10775 in Batch 22 is done
# Row 10776 in Batch 22 is done
# Row 10777 in Batch 22 is done
# Row 10778 in Batch 22 is done
# Row 10779 in Batch 22 is done
# Row 10780 in Batch 22 is done
# Row 10781 in Batch 22 is done
# Row 10782 in Batch 22 is done
# Row 10783 in Batch 22 is done
# Row 10784 in Batch 22 is done
# Row 10785 in Batch 22 is done
# Row 10786 in Batch 22 is done
# Row 10787 in Batch 22 is done
# Row 10788 in Batch 22 is done
# Row 10789 in Batch 22 is done
# Row 10790 in Batch 22 is done
# Row 10791 in Batch 22 is done
# Row 10792 in Batch 22 is done
# Row 10793 in Batch 22 is done
# Row 10794 in Batch 22 is done
# Row 10795 in Batch 22 is done
# Row 10796 in Batch 22 is done
# Row 10797 in Batch 22 is done
# Row 10798 in Batch 22 is done
# Row 10799 in Batch 22 is done
# Row 10800 in Batch 22 is done
# Row 10801 in Batch 22 is done
# Row 10802 in Batch 22 is done
# Row 10803 in Batch 22 is done
# Row 10804 in Batch 22 is done
# Row 10805 in Batch 22 is done
# Row 10806 in Batch 22 is done
# Row 10807 in Batch 22 is done
# Row 10808 in Batch 22 is done
# Row 10809 in Batch 22 is done
# Row 10810 in Batch 22 is done
# Row 10811 in Batch 22 is done
# Row 10812 in Batch 22 is done
# Row 10813 in Batch 22 is done
# Row 10814 in Batch 22 is done
# Row 10815 in Batch 22 is done
# Row 10816 in Batch 22 is done
# Row 10817 in Batch 22 is done
# Row 10818 in Batch 22 is done
# Row 10819 in Batch 22 is done
# Row 10820 in Batch 22 is done
# Row 10821 in Batch 22 is done
# Row 10822 in Batch 22 is done
# Row 10823 in Batch 22 is done
# Row 10824 in Batch 22 is done
# Row 10825 in Batch 22 is done
# Row 10826 in Batch 22 is done
# Row 10827 in Batch 22 is done
# Row 10828 in Batch 22 is done
# Row 10829 in Batch 22 is done
# Row 10830 in Batch 22 is done
# Row 10831 in Batch 22 is done
# Row 10832 in Batch 22 is done
# Row 10833 in Batch 22 is done
# Row 10834 in Batch 22 is done
# Row 10835 in Batch 22 is done
# Row 10836 in Batch 22 is done
# Row 10837 in Batch 22 is done
# Row 10838 in Batch 22 is done
# Row 10839 in Batch 22 is done
# Row 10840 in Batch 22 is done
# Row 10841 in Batch 22 is done
# Row 10842 in Batch 22 is done
# Row 10843 in Batch 22 is done
# Row 10844 in Batch 22 is done
# Row 10845 in Batch 22 is done
# Row 10846 in Batch 22 is done
# Row 10847 in Batch 22 is done
# Row 10848 in Batch 22 is done
# Row 10849 in Batch 22 is done
# Row 10850 in Batch 22 is done
# Row 10851 in Batch 22 is done
# Row 10852 in Batch 22 is done
# Row 10853 in Batch 22 is done
# Row 10854 in Batch 22 is done
# Row 10855 in Batch 22 is done
# Row 10856 in Batch 22 is done
# Row 10857 in Batch 22 is done
# Row 10858 in Batch 22 is done
# Row 10859 in Batch 22 is done
# Row 10860 in Batch 22 is done
# Row 10861 in Batch 22 is done
# Row 10862 in Batch 22 is done
# Row 10863 in Batch 22 is done
# Row 10864 in Batch 22 is done
# Row 10865 in Batch 22 is done
# Row 10866 in Batch 22 is done
# Row 10867 in Batch 22 is done
# Row 10868 in Batch 22 is done
# Row 10869 in Batch 22 is done
# Row 10870 in Batch 22 is done
# Row 10871 in Batch 22 is done
# Row 10872 in Batch 22 is done
# Row 10873 in Batch 22 is done
# Row 10874 in Batch 22 is done
# Row 10875 in Batch 22 is done
# Row 10876 in Batch 22 is done
# Row 10877 in Batch 22 is done
# Row 10878 in Batch 22 is done
# Row 10879 in Batch 22 is done
# Row 10880 in Batch 22 is done
# Row 10881 in Batch 22 is done
# Row 10882 in Batch 22 is done
# Row 10883 in Batch 22 is done
# Row 10884 in Batch 22 is done
# Row 10885 in Batch 22 is done
# Row 10886 in Batch 22 is done
# Row 10887 in Batch 22 is done
# Row 10888 in Batch 22 is done
# Row 10889 in Batch 22 is done
# Row 10890 in Batch 22 is done
# Row 10891 in Batch 22 is done
# Row 10892 in Batch 22 is done
# Row 10893 in Batch 22 is done
# Row 10894 in Batch 22 is done
# Row 10895 in Batch 22 is done
# Row 10896 in Batch 22 is done
# Row 10897 in Batch 22 is done
# Row 10898 in Batch 22 is done
# Row 10899 in Batch 22 is done
# Row 10900 in Batch 22 is done
# Row 10901 in Batch 22 is done
# Row 10902 in Batch 22 is done
# Row 10903 in Batch 22 is done
# Row 10904 in Batch 22 is done
# Row 10905 in Batch 22 is done
# Row 10906 in Batch 22 is done
# Row 10907 in Batch 22 is done
# Row 10908 in Batch 22 is done
# Row 10909 in Batch 22 is done
# Row 10910 in Batch 22 is done
# Row 10911 in Batch 22 is done
# Row 10912 in Batch 22 is done
# Row 10913 in Batch 22 is done
# Row 10914 in Batch 22 is done
# Row 10915 in Batch 22 is done
# Row 10916 in Batch 22 is done
# Row 10917 in Batch 22 is done
# Row 10918 in Batch 22 is done
# Row 10919 in Batch 22 is done
# Row 10920 in Batch 22 is done
# Row 10921 in Batch 22 is done
# Row 10922 in Batch 22 is done
# Row 10923 in Batch 22 is done
# Row 10924 in Batch 22 is done
# Row 10925 in Batch 22 is done
# Row 10926 in Batch 22 is done
# Row 10927 in Batch 22 is done
# Row 10928 in Batch 22 is done
# Row 10929 in Batch 22 is done
# Row 10930 in Batch 22 is done
# Row 10931 in Batch 22 is done
# Row 10932 in Batch 22 is done
# Row 10933 in Batch 22 is done
# Row 10934 in Batch 22 is done
# Row 10935 in Batch 22 is done
# Row 10936 in Batch 22 is done
# Row 10937 in Batch 22 is done
# Row 10938 in Batch 22 is done
# Row 10939 in Batch 22 is done
# Row 10940 in Batch 22 is done
# Row 10941 in Batch 22 is done
# Row 10942 in Batch 22 is done
# Row 10943 in Batch 22 is done
# Row 10944 in Batch 22 is done
# Row 10945 in Batch 22 is done
# Row 10946 in Batch 22 is done
# Row 10947 in Batch 22 is done
# Row 10948 in Batch 22 is done
# Row 10949 in Batch 22 is done
# Row 10950 in Batch 22 is done
# Row 10951 in Batch 22 is done
# Row 10952 in Batch 22 is done
# Row 10953 in Batch 22 is done
# Row 10954 in Batch 22 is done
# Row 10955 in Batch 22 is done
# Row 10956 in Batch 22 is done
# Row 10957 in Batch 22 is done
# Row 10958 in Batch 22 is done
# Row 10959 in Batch 22 is done
# Row 10960 in Batch 22 is done
# Row 10961 in Batch 22 is done
# Row 10962 in Batch 22 is done
# Row 10963 in Batch 22 is done
# Row 10964 in Batch 22 is done
# Row 10965 in Batch 22 is done
# Row 10966 in Batch 22 is done
# Row 10967 in Batch 22 is done
# Row 10968 in Batch 22 is done
# Row 10969 in Batch 22 is done
# Row 10970 in Batch 22 is done
# Row 10971 in Batch 22 is done
# Row 10972 in Batch 22 is done
# Row 10973 in Batch 22 is done
# Row 10974 in Batch 22 is done
# Row 10975 in Batch 22 is done
# Row 10976 in Batch 22 is done
# Row 10977 in Batch 22 is done
# Row 10978 in Batch 22 is done
# Row 10979 in Batch 22 is done
# Row 10980 in Batch 22 is done
# Row 10981 in Batch 22 is done
# Row 10982 in Batch 22 is done
# Row 10983 in Batch 22 is done
# Row 10984 in Batch 22 is done
# Row 10985 in Batch 22 is done
# Row 10986 in Batch 22 is done
# Row 10987 in Batch 22 is done
# Row 10988 in Batch 22 is done
# Row 10989 in Batch 22 is done
# Row 10990 in Batch 22 is done
# Row 10991 in Batch 22 is done
# Row 10992 in Batch 22 is done
# Row 10993 in Batch 22 is done
# Row 10994 in Batch 22 is done
# Row 10995 in Batch 22 is done
# Row 10996 in Batch 22 is done
# Row 10997 in Batch 22 is done
# Row 10998 in Batch 22 is done
# Row 10999 in Batch 22 is done
# Row 11000 in Batch 22 is done
# Row 11001 in Batch 22 is done
# Row 11002 in Batch 22 is done
# Row 11003 in Batch 22 is done
# Row 11004 in Batch 22 is done
# Row 11005 in Batch 22 is done
# Row 11006 in Batch 22 is done
# Row 11007 in Batch 22 is done
# Row 11008 in Batch 22 is done

# %%
df.head()
# Out:
#                                       review_content  Sentiment
# 0     Looks durable Charging is fine tooNo complains          4
# 1             Charging is really fast, good product.          4
# 2               Till now satisfied with the quality.          4
# 3  This is a good product . The charging speed is...          4
# 4                      Good quality, would recommend          4

# %% [markdown]
# ## Save results to CSV

# %%
csv_path_save = "../raw_data/reviews_analyzed.csv"

# %%
df.to_csv(csv_path_save, index=False)

# %% [markdown]
# - nothing i am aware of :)

# %%
file_path_save = "../raw_data/reviews_analyzed.csv"

# %%
df.to_csv(csv_file_path, index=TRUE)

# %% [markdown]
# # Function to predict and give alternative suggestion

# %%
#from fastapi import FastAPI
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
import random
#app = FastAPI()

#@app.get("/")
def index():
    return {"title": "Hello Arthur"}

#@app.get("/predict")
def predict(review):
    tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
    model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
    tokens = tokenizer.encode(review, return_tensors="pt")
    result = model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
# Raw File
file_path = "../raw_data/summary_keywords_df.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B002PD61Y4  D-Link DWA-131 300 Mbps Wireless Nano USB Adap...
# 1  B002SZEOLG  TP-Link Nano USB WiFi Dongle 150Mbps High Gain...
# 2  B003B00484  Duracell Plus AAA Rechargeable Batteries (750 ...
# 3  B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# 4  B004IO5BMQ  Logitech M235 Wireless Mouse, 1000 DPI Optical...
#
#         product_category                                            summary  \
# 0    WirelessUSBAdapters  Good quality tool from d linkWiFi signal is go...
# 1    WirelessUSBAdapters  The wifi dongle is a simple plug & play device...
# 2  RechargeableBatteries  Soldering the connections was bit tricky but i...
# 3                   Mice  The best thing about this mouse is that u can ...
# 4                   Mice  Good product, but too smaller than the regular...
#
#                                             keywords  sentiment
# 0  ['dvr works', 'wifi supporting', 'jio wifi', '...          4
# 1  ['usb tethering', 'best adapter', 'wifi dongle...          4
# 2  ['trimmer battery', 'qt4005 trimmer', 'expensi...          4
# 3  ['mouse quality', 'best mouse', 'mouse budget'...          5
# 4  ['sized battery', 'mouse easy', 'mouse', 'mous...          4

# %%
df[(df['product_category'] == 'Mice') & (df['sentiment'].isin(good_review_score))].drop(columns=['product_category','keywords','sentiment'])
# Out:
#       product_id                                       product_name  \
# 3     B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# 4     B004IO5BMQ  Logitech M235 Wireless Mouse, 1000 DPI Optical...
# 177   B01HJI0FS2  Dell MS116 1000Dpi USB Wired Optical Mouse, Le...
# 186   B01KK0HU3Y  HP Z3700 Wireless Optical Mouse with USB Recei...
# 205   B01MQ2A86A  Logitech M331 Silent Plus Wireless Mouse, 2.4G...
# 237   B073BRXPZX  Lenovo 300 Wired Plug & Play USB Mouse, High R...
# 332   B07J2NGB69  Lenovo 400 Wireless Mouse, 1200DPI Optical Sen...
# 343   B07JPX9CR7  Dell WM118 Wireless Mouse, 2.4 Ghz with USB Na...
# 362   B07L9FW9GF  Zebronics Zeb-Power Wired USB Mouse, 3-Button,...
# 467   B07X2L5Z8C  Logitech Pebble M350 Wireless Mouse with Bluet...
# 530   B083RCTXLL  HP X200 Wireless Mouse with 2.4 GHz Wireless c...
# 680   B08LW31NQ6  Lenovo 600 Bluetooth 5.0 Silent Mouse: Compact...
# 845   B098JYT4SY  Zebronics Zeb-Jaguar Wireless Mouse, 2.4GHz wi...
# 861   B099SD8PRP  Lenovo 130 Wireless Compact Mouse, 1K DPI Opti...
# 1121  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 1150  B0B296NTFV  Portronics Toad 23 Wireless Optical Mouse with...
#
#                                                 summary
# 3     The best thing about this mouse is that u can ...
# 4     Good product, but too smaller than the regular...
# 177   Good for gaming by the way. Suits my hand the ...
# 186   It's so smooth to use this. No pressure on han...
# 205   Like : Very soft to hand. No clicking sound. V...
# 237   It does the job and cable is strong enough. De...
# 332   The most important flaw there are times I forg...
# 343   The wireless mouse is working well. There is o...
# 362   You can also do decent gaming with this mouse....
# 467   It's a good bluetooth mouse. Connects within 1...
# 530   The mouse looks good, and it is even easy to h...
# 680   This is the perfect mouse for office, its comf...
# 845   very good producteasy to handleuse of dpi is a...
# 861   Great mouse for daily office use. After 1 mont...
# 1121  The mouse is super comfortable in my hand. The...
# 1150  Mouse is good and working smoothly. Light weig...

# %%
def predict_and_recommed(product_category, review):
    #good_review_score = [4, 5]
    if predict(review) < 4:
        if 5 in df['sentiment'].values:
            print(f'It looks like you are not too happy with this product. Try taking a look at these products under {product_category}:')
            return df[(df['product_category'] == product_category) & (df['sentiment'] == 5)].drop(columns=['product_category','keywords','sentiment'])
        else:
            print(f'It looks like you are not too happy with this product. Try taking a look at these products under {product_category}:')
            return df[(df['product_category'] == product_category) & (df['sentiment'] == 4)].drop(columns=['product_category','keywords','sentiment'])
    elif predict(review) == 4:
            print(f'Thank you for your feedback. Here are some other products with better reviews under {product_category}:')
            return df[(df['product_category'] == product_category) & (df['sentiment'] == 5)].drop(columns=['product_category','keywords','sentiment'])
    else:
        print('Great choice!')

# %%
## Input
your_product_category = "Mice"
your_review = "This mouse is pretty good." #"Great mouse" #"This mouse is bad. Would not buy again."

# %%
## Output
predict_and_recommed(your_product_category, your_review)
# Out:
# Thank you for your feedback. Here are some other products with better reviews under Mice:
#       product_id                                       product_name  \
# 3     B003L62T7W  Logitech B100 Wired USB Mouse, 3 yr Warranty, ...
# 177   B01HJI0FS2  Dell MS116 1000Dpi USB Wired Optical Mouse, Le...
# 186   B01KK0HU3Y  HP Z3700 Wireless Optical Mouse with USB Recei...
# 467   B07X2L5Z8C  Logitech Pebble M350 Wireless Mouse with Bluet...
# 680   B08LW31NQ6  Lenovo 600 Bluetooth 5.0 Silent Mouse: Compact...
# 845   B098JYT4SY  Zebronics Zeb-Jaguar Wireless Mouse, 2.4GHz wi...
# 861   B099SD8PRP  Lenovo 130 Wireless Compact Mouse, 1K DPI Opti...
# 1121  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#                                                 summary
# 3     The best thing about this mouse is that u can ...
# 177   Good for gaming by the way. Suits my hand the ...
# 186   It's so smooth to use this. No pressure on han...
# 467   It's a good bluetooth mouse. Connects within 1...
# 680   This is the perfect mouse for office, its comf...
# 845   very good producteasy to handleuse of dpi is a...
# 861   Great mouse for daily office use. After 1 mont...
# 1121  The mouse is super comfortable in my hand. The...
